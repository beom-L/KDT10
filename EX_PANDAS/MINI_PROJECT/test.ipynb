# %% [markdown]
# ### [ 엑셀 읽어와서 분석하기 ]

# %%
## 모듈
import pandas as pd
import numpy as np

## 파일 경로 설정
DATA_FILE = './Data/[한국에너지공단] 자동차 연비표시제도 정보.xlsx'

## 파일 읽기
dataDF = pd.read_excel(DATA_FILE)

display(dataDF)
# Out:
# c:\Users\qjadl\anaconda3\envs\DATA_311\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#           순번    년도                             모델명   제조사   유종     배기량  \
# 0          1  2019       쏘나타(LF)개조차 2.0LPI MT (15)    현대  LPG  1999.0
# 1          2  2019                BMW X3 xDrive20d   BMW   경유  1995.0
# 2          3  2019                  레인지로버 이보크 2.0D  랜드로버   경유  1999.0
# 3          4  2019          GV70 2.5T-GDI 2WD 21인치    현대  휘발유  2497.0
# 4          5  2019                  코나 전기자동차 (도심형)    현대   전기     0.0
# ...      ...   ...                             ...   ...  ...     ...
# 16437  24690  2025       K7 2.4하이브리드 (17"타이어) (15)    기아  NaN     NaN
# 16438  24691  2025    니로 1.6GDI 하이브리드_18''타이어 (15)    기아  NaN     NaN
# 16439  24692  2025    니로 1.6GDI 하이브리드_16''타이어 (15)    기아  NaN     NaN
# ...

# %% [markdown]
# ### 공통 작업  <hr>
# 1. 평균 주행 거리
# 2. 에너지 단가
# 3. 연비 (또는 전비)
# 4. CO2 배출량
# 5. 5년 유지비

# %%
## 항이브리드 출력 = > 전기+휘발유

dataDF2 = dataDF[(dataDF['유종'] == '전기+휘발유') | (dataDF['등급'] == 'PHEV') | (dataDF['등급'] == 'HEV') ]
dataDF2
# Out:
#           순번    년도                                 모델명  제조사      유종     배기량  \
# 33        34  2019              BMW 745Le iPerformance  BMW  전기+휘발유  2998.0
# 38        39  2019                       볼보 XC60T8 AWD   볼보  전기+휘발유  1969.0
# 69        70  2019                            BMW 530e  BMW  전기+휘발유  1998.0
# 93        94  2019               BMW 740e iPerformance  BMW  전기+휘발유  1998.0
# 95        96  2019               BMW 745e iPerformance  BMW  전기+휘발유  2998.0
# ...      ...   ...                                 ...  ...     ...     ...
# 12644  20895  2025                     GLC350 e 4Matic   벤츠     NaN     NaN
# 12645  20896  2025         K5(JF) 2.0GDI 플러그인하이브리드 개조차   기아     NaN     NaN
# 12646  20897  2025                     GLC350 e 4Matic   벤츠     NaN     NaN
# 12647  20898  2025  니로(DE) 1.6GDI 플러그인 하이브리드_6DCT (15)   기아     NaN     NaN
# 12648  20899  2025     아이오닉 1.6GDI 플러그인하이브리드_6DCT (15)   현대     NaN     NaN
#
# ...

# %%
dataDF2 = dataDF2.reset_index(drop=True)
dataDF2['순번'] = dataDF2.index + 1
dataDF2
# Out:
#       순번    년도                                모델명  제조사      유종     배기량  \
# 0      1  2019             BMW 745Le iPerformance  BMW  전기+휘발유  2998.0
# 1      2  2019                      볼보 XC60T8 AWD   볼보  전기+휘발유  1969.0
# 2      3  2019                           BMW 530e  BMW  전기+휘발유  1998.0
# 3      4  2019              BMW 740e iPerformance  BMW  전기+휘발유  1998.0
# 4      5  2019              BMW 745e iPerformance  BMW  전기+휘발유  2998.0
# ..   ...   ...                                ...  ...     ...     ...
# 295  296  2024    페라리 SF90 Spider Assetto Fiorano  페라리  전기+휘발유  3990.0
# 296  297  2024                  페라리 SF90 Stradale  페라리  전기+휘발유  3990.0
# 297  298  2024  페라리 SF90 Stradale Assetto Fiorano  페라리  전기+휘발유  3990.0
# 298  299  2024                 페라리 SF90 XX Spider  페라리  전기+휘발유  3990.0
# 299  300  2024               페라리 SF90 XX Stradale  페라리  전기+휘발유  3990.0
#
#      Unnamed: 6      복합연비    등급  Unnamed: 9  1회충전주행거리 고속도로연비 도심연비 자동차종류   유형
# ...

# %%
# dataDF2.to_excel("./Data/전기+휘발유_정리파일.xlsx")
