# %% [markdown]
# ### 박스오피스 영화 스크롤링 및 분석

# %%
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
import pandas as pd

# ------------------------------------------------------
# 0) 분석
# ------------------------------------------------------
# ## 첫번째 영화 제목의 주소
# #main_pack > div.sc_new.cs_common_module.case_list.color_5._au_movie_list_content_wrap > div.cm_content_wrap > div > div > div.mflick > div._panel_popular._tab_content > div.list_image_info.type_pure_top > div > ul:nth-child(1) > li:nth-child(1) > a > div > div.title_box > strong
# -> '#main_pack div.list_image_info.type_pure_top ul'  : 이렇게 정리해야함



# ------------------------------------------------------
# 1) 현재 상영 영화 페이지 불러오기
# ------------------------------------------------------
## 주소 불러와서 urlopen하는건 encoding 에러 발생해서 다른 방법으로 해결
url = "https://movie.naver.com/movie/running/current.naver"
req = Request(url, headers={"User-Agent": "Mozilla/5.0"})
html = urlopen(req).read().decode("utf-8", "ignore")
htmlBS = BeautifulSoup(html, "html.parser")

htmlBS




## 다음으로 클릭하는 버튼
# Out:
# <!DOCTYPE html>
#  <html lang="ko"><head> <meta charset="utf-8"/> <meta content="strict-origin-when-cross-origin" name="referrer"/> <meta content="telephone=no,address=no,email=no" name="format-detection"/> <meta content="현재상영영화 : 네이버 검색" property="og:title"> <meta content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png" property="og:image"/> <meta content="'현재상영영화'의 네이버 검색 결과입니다." property="og:description"/> <meta content="'현재상영영화'의 네이버 검색 결과입니다." lang="ko" name="description"/> <title>현재상영영화 : 네이버 검색</title> <link href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_32x32_240820.ico" rel="shortcut icon"/> <link href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" rel="search" title="Naver" type="application/opensearchdescription+xml"><script> if (top.frames.length!=0 || window!=top) window.open(location, "_top"); </script><link href="https://ssl.pstatic.net/sstatic/search/pc/css/search1_251023.css" rel="stylesheet" type="text/css"/> <link href="https://ssl.pstatic.net/sstatic/search/pc/css/search2_251023.css" rel="stylesheet" type="text/css"/> <link href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_autocomplete_250925.css" rel="stylesheet" type="text/css"/><script> naver = window.naver || {}; naver.search = naver.search || {}; naver.search.abt_param = ""; </script><script> naver = window.naver || {}; naver.search = naver.search || {}; naver.search.error = (function () { var errorList = Array() ; return { add : function (s) { errorList.push(s) ; }, clear : function () { delete errorList ; }, get : function (s) { return errorList ; }, getString : function (d) { if (typeof d === 'undefined') d = '|' ; return errorList.join(d) ; } } })(); function nx_add_event_handler (event, func) { $Fn(func).attach(document, event) ; } function bt(id, after) { document.getElementById(id).src = after; } function document_write (s) { document.write(s) ; } </script><script> var nx_au_cookie_domain = ".search.naver.com" ; var g_site = "" ; function nx_defer_eval (id) { var codeElement = document.getElementById(id), code = codeElement.innerHTML; eval(code.replace(/\/\*/, '').replace(/\*\//, '')); } function trim_crlf (q) { var crlf = /[\r|\n]/ ; q = q.replace(crlf, "") ; return q ; } function include_script (type, defer, src, charset) { var script = document.createElement("script") ; script.type = type, script.defer = defer ; script.src = src ; if (charset) script.charset = charset ; else script.charset = 'utf-8' ; document.getElementsByTagName('head')[0].appendChild(script) ; return script ; } function include_style (src, charset) { var h = document.getElementsByTagName("head")[0] ; var l = document.createElement('link') ; l.type = 'text/css' ; l.rel = 'stylesheet' ; if (charset) l.charset = charset ; else l.charset = 'utf-8' ; l.media = 'screen' ; l.href = src ; h.appendChild(l) ; } function rank_val (rank, name, sign, number, ad_onair) { this.rank = rank ; this.name = name ; this.sign = sign ; this.number = number ; this.ad_onair = ad_onair ; } function rr_hotquery_val (titleImg, totalLink, ad_onair) { this.titleImg = titleImg ; this.totalLink = totalLink ; this.ad_onair = ad_onair ; } function rr_append () { for (var i=0; i<rr_list.length; i++) if (rr_list[i].qname==hotqry_Name && rr_list[i].dir==hotqry_Dir) return 0 ; var o = { order:hotqry_Order, contid:hotqry_ContID, qname:hotqry_Name, dir:hotqry_Dir, toprank:hotqry_TopRank, rankdown:hotqry_RankDown, clicklog:hotqry_ClickLog, toprank_idx:toprank_idx, lowrank_idx:lowrank_idx, topranklist:toprank, lowranklist:lowrank_idx>=0?lowrank:null } ; rr_list = rr_list.concat(o) ; return 1 ; } var msg_hidden_idle=null; function msg (id) { if(msg_hidden_idle) clearInterval(msg_hidden_idle); if(id) { var mid=document.getElementById(id); mid.style.display=''; mid.style.visibility='visible'; } } function msg_hidden (id, f) { if(f) hidden(id); else msg_hidden_idle=setInterval("hidden('"+id+"')",100); } function hidden (id) { var mid=document.getElementById(id); mid.style.display=' ...
# <link href="https://ad-creative.pstatic.net/static/6810970f14e827fad4d415fb/671c30b/build/static/css/main.d92fc186.css" rel="stylesheet"><div class="pcPowerLink_b146" id="pcPowerLink_b146-j4x6"><link href="https://ssl.pstatic.net/sstatic/search/local/css/maps_openapi_https_150716.css" rel="stylesheet"><div class="sc_new ad_section section _pl_section bg_type_v2"><div class="api_subject_bx"><div class="mod_title_area"><div class="title_wrap"><h2 class="title">파워링크</h2><span class="sub"><span class="title_text"><em class="dsc_ncaution_quotation">‘</em> <strong class="dsc_ncaution_keyword">현재상영영화</strong> <em class="dsc_ncaution_quotation">’</em>관련 광고입니다. </span></span><a class="api_ad_link" href="javascript:void(0);" onclick='adInfoShowPl(this)&amp;&amp;goOtherCR(this,"a=pwl_thm*n.adset&amp;r=0&amp;i=pwl_thm*nadset&amp;u="+urlencode(this.href))' role="button"><i class="spnew api_ico_alert">이 광고가 표시된 이유</i></a></div><div class="title_sub"><a class="sub_link" href="//saedu.naver.com/adbiz/searchad/clickChoice.naver" onclick='return goOtherCR(this,"a=pwl_thm*n.registration&amp;r=0&amp;i=pwl_thm*nregistration&amp;u="+urlencode(this.href))' target="_blank">등록 안내</a></div><div class="ly_api_info" style="display: none;"><p class="dsc">이 광고는 사이트검색광고(파워링크)로, 검색어와 광고의 연관도, 광고주의 입찰가 등에 의해 광고 노출 여부와 순위가 결정됩니다.</p><div class="btn_area"><a class="link" href="https://help.naver.com/service/5626/contents/1419">도움말</a></div><button class="btn_close" onclick="adInfoHidePl()" type="button"><i class="spnew ico_close">정보확인 레이어 닫기</i></button></div></div><div class="nad_area" id="power_link_body" impression-event-url="https://ader.naver.com/v1/kwmb56-p-bYlB6CoFW1F38v2w2igWf__oRn7myf64EbB7kS5BQpTRkgwibqBWjwLuTtt7dcGZIclMkGDiPMKM5L7YnZ3sQAlYxgg2SEc6T0aCpniJSwMNiApL9XpW3uv?d=1&amp;c=naver.search.pc.plsearch"><ul class="lst_type"><li class="lst js-hover-item type_img ext_desc type_subtitle" num=""> <a class="lnk_thumb" href="https://ader.naver.com/v1/kwmb56-p-bYlB6CoFW1F38v2w2igWf__oRn7myf64EY6iJj6wFdmOmP9o0gxxUKIXqX6EKGhjqvtUCRHBkURz-S72Di0_sN1XaejKvJdMLFxXvxfn5l22RN1oGEDwQLw0t1jYMrVGuFzbceiNU_45cpXuceGEPZBzUxAwbXtbLdIa0YwHFsF0FDOvmKxXKm2J68kcPjhvSpdS1_PESnVxWX-wJtuh3XK9VfOqGpfg_WthEqI6Y8-nG0H35klNBQkqO383tUhXNprKnfKqWhhBA==?c=naver.search.pc.plsearch&amp;t=0" onclick='return goOtherCR(this,"a=pwl_thm*n.image&amp;r=1&amp;i=nad-a001-01-000000164028915&amp;d="+urlencode("http://smart-file.kr")+"&amp;u="+urlencode(this.href))' target="_blank"><img alt="링크이미지" class="img_thumb" src="https://searchad-phinf.pstatic.net/MjAyMTEwMTlfMTk3/MDAxNjM0NjM1MjY0OTY4.ODF8flbb11Osk4xH18jiDBjRyOkWCWMsX_rjfnoZtecg.Au9NGoFNKl51lkyoc-uZVE2fqd0zmQ93-6sJVx6U_GMg.JPEG/1785701-bef27930-81ca-4536-a522-8da2d477ad09.jpg?type=f160_160"> </img></a><div class="inner"><div class="title_url_area"><div class="url_area"><a class="favicon_wrap" href="https://ader.naver.com/v1/kwmb56-p-bYlB6CoFW1F38v2w2igWf__oRn7myf64EY6iJj6wFdmOmP9o0gxxUKIXqX6EKGhjqvtUCRHBkURz-S72Di0_sN1XaejKvJdMLFxXvxfn5l22RN1oGEDwQLwrsqnepOXapEw9i-oJWolnkQeDtsIfK9Sukwl4lbhytd2QNlti70sqIZriy_O7qOZ3kIE_Pae_pd0G-7TShRuQG01tT7wG36M4fhWkG91CQCNYKEBcU8sx3C1tICVgA_w?c=naver.search.pc.plsearch&amp;t=0" onclick='return goOtherCR(this,"a=pwl_thm*n.favicon&amp;r=1&amp;i=nad-a001-01-000000164028915&amp;d="+urlencode("http://smart-file.kr")+"&amp;u="+urlencode(this.href))' target="_blank"> <img alt="favicon" class="icon_favicon" data-img-alias="power-link-favicon-error" data-lazysrc="https://search.pstatic.net/sunny?src=https%3A%2F%2Fsmart-file.kr%2Ffavicon.ico&amp;type=f30_30_png_expire24" height="16" src="https://ssl.pstatic.net/adimg3.search/imp/nx/power/pc/251001/img/icon_favicon.png" width="16"> </img></a> <span aria-label="광고" class="ad_mark" role="img"><svg fill="none" height="18" viewbox="0 0 27 18" width="27" xmlns="http://www.w3.org/2000/svg"><rect height="17" rx="8.5" stroke="var(--core-color-light-gray-400)" width="26" x="0.5" y="0.5"></rect><path d="M12.096 11.988C12.096 13.121 10.831 13.814 8.763 13.814C6.695 13.814 5.4 ...
# <script>
# window.__ADFE_TEMPLATE__ = window.__ADFE_TEMPLATE__ || {};
# window.__ADFE_TEMPLATE__.pcPowerLink_b146 = window.__ADFE_TEMPLATE__.pcPowerLink_b146 || [];
# window.__ADFE_TEMPLATE__.pcPowerLink_b146.push([document.getElementById('pcPowerLink_b146-j4x6'),{},{}]);
# </script><script src="https://ad-creative.pstatic.net/static/6810970f14e827fad4d415fb/671c30b/build/static/js/main.8036fa75.js"></script>
# </link></section>
# <div class="_scrollLog" data-slog-id="pwl_thm*n" style="visibility:hidden;height:0px;margin:0 28px"></div><link href="https://ntalk.pstatic.net/webkit/3.2.3/webkit.css" rel="stylesheet" type="text/css"> <div class="ntalk_wrap _opentalk_n120o3"> <div id="_opentalk_loading_n120o3"> <section class="sp_nchat sc_new"> <div class="api_subject_bx"> <div class="api_title_area"> <h2 class="api_title"> <span class="title">오픈톡</span> </h2> </div> <div class="error_wrap" style="padding: 16px 16px 16px;height:145px"> <div class="api_error_wrap" style="padding:65px 0 65px;border-radius:12px;background:rgba(var(--gray95),1);"> <div class="api_loading"> <div class="api_load_wrap"> <div class="api_load type_grey"> <div class="load_dot dot1"></div> <div class="load_dot dot2"></div> <div class="load_dot dot3"></div> <div class="load_dot dot4"></div> <div class="load_dot dot5"></div> <div class="load_dot dot6"></div> </div> </div> <p class="dsc_loading blind">정보를 가져오는 중입니다.</p> </div> </div> </div> </div> </section> </div> <div id="_webkit_n120o3" style="display: none"></div> </div> <script>(function(){var jsUrl="https://ssl.pstatic.net/sstatic/fe/sfe/open-talk/SearchTalk.min_230920";var openChatUrl="https://ntalk.pstatic.net/webkit/3.2.3/webkit.umd.min";var startApplication=function(){var require=window.require.config({"context":"xiu","paths":{"search-talk":jsUrl.replace(/\.js$/,""),"@naver-open-chat":openChatUrl.replace(/\.js$/,"")}});define("jquery",[],function(){return jQuery;});require(["jquery","search-talk","@naver-open-chat"],function($,SearchTalk,webkitTalk){var searchTalk=new SearchTalk({"base":$("._opentalk_n120o3"),"selector":"#_webkit_n120o3","loading":"#_opentalk_loading_n120o3","config":{"darkMode":false,"channelId":"N120O3","boxHeight":495,"clickLogCode":{"titleLink":"nco_xiu*1.opntlk","bestMessage":"nco_xiu*1.topmsg","message":"nco_xiu*1.msg","report":"nco_xiu*1.report","input":"nco_xiu*1.more","preview":"nco_xiu*2.short"},"gdid":"00000000_000002013B3D","searchQuery":"현재상영영화","enableMoreNaverTalks":true,"style":"PC"}});});};var requirejs=naver.common.gv.REQUIRE_JS;naver.common.load_js(window.require?null:requirejs,startApplication,true,150);})();</script> <div class="_scrollLog" data-slog-id="nco_xiu*1" style="visibility:hidden;height:0px;margin:0 28px"></div><link href="https://ssl.pstatic.net/sstatic/fe/fender/client/37298e166784b85d48f0/index.css" rel="stylesheet" type="text/css"><div class="sc_new _slog_visible" data-block-id="ugc/prs_template_ugc_influencer_participation_desk.ts" data-fender-root="true" data-meta-area="ugB_ipR" data-meta-nscs="" data-meta-ssc="tab.nx.all" data-meta-ssuid="intentblock" data-meta-ssuid-extra="fender_renderer-intentblock" data-slog-container="ugB_ipR" id="fdr-8238ed0dc75a4f1b87289e8471d0ac9b"><div class="NqPS577TQ7LukclHQ0FW ER5okOrgCu7G24OMsJlI desktop_mode api_subject_bx"><div class="sds-comps-vertical-layout sds-comps-full-layout fds-ugc-influencer" data-template-id="sdsVerticalLayout"><div class="sds-comps-vertical-layout sds-comps-full-layout sds-comps-header type-basic nbilngyCkYtbXGBUVfAB" data-sds-comp="Header" data-template-id="sdsFeedSearchHeader" data-template-type="basic"><div class="sds-comps-horizontal-layout sds-comps-full-layout sds-comps-header-title"><div class="sds-comps-horizontal-layout sds-comps-inline-layout sds-comps-header-left"><span class="sds-comps-text sds-comps-text-ellipsis sds-comps-text-ellipsis-1 sds-comps-text-type-headline1 sds-comps-text-weight-lg" style="width:auto">영화 인플루언서 콘텐츠</span></div></div></div><div class="sds-comps-vertical-layout sds-comps-full-layout fds-ugc-item-list" data-template-id="sdsVerticalLayout"><div class="sds-comps-base-layout sds-comps-inline-layout TNrzX9Zk7oPQzsli6JNg fender-ui_fde4d857 fender-ui_7108cfb0" data-template-id="ugcItemDesk"><div class="sds-comps-base-layout sds-comps-inline-layout V8EbGrECCoqM2zQwvo1w fender-ui_fde4d857 fender-ui_7108cfb0"><div class="sds-comps-base-layout sds-comps-inline-layout profile-group fender-u ...
# (function () {
#
#   var startApplication = function () {
#     var require = window.require.config({
#       "context": "fender_renderer_37298e166784b85d48f0"
#     });
#     require(["https://ssl.pstatic.net/sstatic/fe/fender/client/37298e166784b85d48f0/index.js"], function (entry) {
#       entry.bootstrap(document.getElementById("fdr-8238ed0dc75a4f1b87289e8471d0ac9b"), {"appElementAttrs":{"data-slog-container":"ugB_ipR","className":"sc_new _slog_visible"},"rootElementAttrs":{"className":"api_subject_bx"},"meta":{"area":"ugB_ipR","query":"현재상영영화","ssc":"tab.nx.all","ssuid":"intentblock","ssuidExtra":"fender_renderer-intentblock","token":"basic"},"refs":{"blockId":"ugc/prs_template_ugc_influencer_participation_desk.ts"},"body":{"props":{"children":[{"props":{"title":"영화 인플루언서 콘텐츠","type":"basic"},"templateId":"sdsFeedSearchHeader"},{"props":{"children":[{"props":{"article":{"content":"최신 개봉 영화 박스오피스 <mark>현재 상영 영화</mark> 순위 <mark>현재 상영 영화</mark> 박스오피스 순위입니다. 황금 연휴가 있었던 10월 극장가도 이제 거의 다 지나갔는데요. &lt;보스&gt; 이후에 한국 영화 최신작이 없었기 때문인지 박스오피스 TOP 3를 모두 외국 영화가 차지했습니다. 그중 두 편이 애니메이션 영화인데요. 지난 주말 1위 역시 &lt;극장판 체인소맨: 레제편&gt;이 무난하게 정상의... ","contentEllipsis":2,"contentHref":"https://in.naver.com/rissnam/contents/internal/881737492249152?areacode=itb_bas%2Af_challenge&query=%ED%98%84%EC%9E%AC%EC%83%81%EC%98%81%EC%98%81%ED%99%94","images":[{"clickLog":{"item":{"element":".imgtitlelink","g":"%7B%22bid%22%3A%22SPC-0000000000008429%22%2C%22docRank%22%3A1%7D","i":"SPC-0000000000008429.a0209rl4_nblog_post_224055754318","r":1,"source":""}},"link":"https://in.naver.com/rissnam/contents/internal/881737492249152?areacode=itb_bas%2Af_challenge&query=%ED%98%84%EC%9E%AC%EC%83%81%EC%98%81%EC%98%81%ED%99%94","src":"https://search.pstatic.net/common/?src=https%3A%2F%2Fmblogthumb-phinf.pstatic.net%2FMjAyNTEwMjdfMTA0%2FMDAxNzYxNTY4NTIyNDc5.HgsmGfz3MBY961Ah_eNyNtLor85CSDa7vjmr5FEc8fMg.2I6tkmRTb4DWhBtGhgjP03jPS2TfFWl7RQMdoXcDHAcg.PNG%2F%25C1%25A6%25B8%25F1%25C0%25BB-%25C0%25D4%25B7%25C2%25C7%25D8%25C1%25D6%25BC%25BC%25BF%25E4_-001_-_2025-10-27T210211.982.png%3Ftype%3Dw800&type=b220"},{"clickLog":{"item":{"element":".imgtitlelink","g":"%7B%22bid%22%3A%22SPC-0000000000008429%22%2C%22docRank%22%3A1%7D","i":"SPC-0000000000008429.a0209rl4_nblog_post_224055754318","r":1,"source":""}},"link":"https://in.naver.com/rissnam/contents/internal/881737492249152?areacode=itb_bas%2Af_challenge&query=%ED%98%84%EC%9E%AC%EC%83%81%EC%98%81%EC%98%81%ED%99%94","src":"https://search.pstatic.net/common/?src=https%3A%2F%2Fmblogthumb-phinf.pstatic.net%2FMjAyNTEwMjdfMTkx%2FMDAxNzYxNTY4NTI0MDAw.j2n_Gng57DWiXHuCd_pRMIqGeQPb5p_2lgCahTHEk-Ag.j10sxTYUgfwTKymCtr9Ke-u0qg-Ag2SstSwSqi8lS2Ig.JPEG%2F1.JPG%3Ftype%3Dw800&type=b220"},{"clickLog":{"item":{"element":".imgtitlelink","g":"%7B%22bid%22%3A%22SPC-0000000000008429%22%2C%22docRank%22%3A1%7D","i":"SPC-0000000000008429.a0209rl4_nblog_post_224055754318","r":1,"source":""}},"link":"https://in.naver.com/rissnam/contents/internal/881737492249152?areacode=itb_bas%2Af_challenge&query=%ED%98%84%EC%9E%AC%EC%83%81%EC%98%81%EC%98%81%ED%99%94","src":"https://search.pstatic.net/common/?src=https%3A%2F%2Fmblogthumb-phinf.pstatic.net%2FMjAyNTEwMjdfMjgz%2FMDAxNzYxNTY4NTI1Njkz.nkOFV4JuvrfXQSQ36dftnRmyvSzLwiP00qqUQ3gNxmog.yTxjrXtu3amltmD4Flo-Syw7etCm_5WhihJ_r_CW1Tgg.JPEG%2F11.JPG%3Ftype%3Dw800&type=b220"},{"clickLog":{"item":{"element":".imgtitlelink","g":"%7B%22bid%22%3A%22SPC-0000000000008429%22%2C%22docRank%22%3A1%7D","i":"SPC-0000000000008429.a0209rl4_nblog_post_224055754318","r":1,"source":""}},"link":"https://in.naver.com/rissnam/contents/internal/881737492249152?areacode=itb_bas%2Af_challenge&query=%ED%98%84%EC%9E%AC%EC%83%81%EC%98%81%EC%98%81%ED%99%94","src":"https://search.pstatic.net/common/?src=https%3A%2F%2Fmblogthumb-phinf.pstatic.net%2FMjAyNTEwMjdfMjUz%2FMDAxNzYxNTY4NTI3MTIz.IN-npPUwHk5cDTA-65zhxAf8Gi5ybC-hK2xJ3ItweUcg.1TzE2JLjChbKCYA8djK2DIS_b_m8W3cvUwadrWXepSYg.JPEG%2F13.JPG%3Ftype%3Dw800&type=b220"},{"clickLog":{"item":{"element":".imgtitlelink","g":"%7B%22bid%22%3A%22SPC-0000000000008429%22%2C%22docRank%22%3A1%7D","i":"SPC-0000000000008429.a0209rl4_nblog_post_224055754318","r":1,"source":""}},"link":"https://in.naver.com/rissnam/contents/internal/881737492249152?areacode=itb_bas%2Af_challenge&query=%ED%98%84%EC%9E%AC%EC%83%81 ...
#
#       }});
#     });
#   };
#
#   if (window.naver && window.naver.common && typeof window.naver.common.load_js === "function") {
#     var isDomLoading = document.readyState === "loading";
#
#     naver.common.load_js(null, startApplication, isDomLoading, 150, !isDomLoading);
#   } else {
#     setTimeout(startApplication, 150);
#   }
# })();
# </script><div class="_scrollLog" data-slog-id="ugB_ipR*f" style="visibility:hidden;height:0px;margin:0 28px"></div><div class="sc_new _slog_visible" data-block-id="" data-fender-root="true" data-meta-area="ugB_b1R" data-meta-nscs="" data-meta-ssc="tab.nx.all" data-meta-ssuid="intentblock" data-meta-ssuid-extra="fender_renderer-intentblock" data-slog-container="ugB_b1R" id="fdr-a1ccf33168974c15a54cc54369be8b52"><div class="NqPS577TQ7LukclHQ0FW ER5okOrgCu7G24OMsJlI desktop_mode api_subject_bx"><div class="sds-comps-base-layout sds-comps-inline-layout fds-collection-root fender-ui_fde4d857 fender-ui_7108cfb0"><div class="UbnHCsVY_gMjvY4FVn7P"><div class="qO60D9BO5ZMTFlfTA7bg"><div class="RMgFtvhfCnIk3CHLIbEO"><span class="fds-comps-text fds-comps-header-headline fender-ui_2df0ec64">현재상영영화 어린이</span></div></div></div><div class="sds-comps-base-layout sds-comps-inline-layout fds-ugc-block-mod-list fender-ui_fde4d857 fender-ui_7108cfb0"><div class="sds-comps-base-layout sds-comps-inline-layout fds-ugc-block-mod fender-ui_fde4d857 fender-ui_7108cfb0"><div class="sds-comps-base-layout sds-comps-inline-layout _keep_wrap fds-article-simple-box fds-article-box-mobilefalse fender-ui_fde4d857 fender-ui_7108cfb0"><div class="sds-comps-base-layout sds-comps-inline-layout fds-thumb-simple-group fender-ui_fde4d857 fender-ui_7108cfb0"><a class="fender-ui_228e3bd1 fds-thumb-anchor" data-heatmap-target=".profile" href="https://in.naver.com/hyunjee1110?areacode=itb_bas%2Af_other&amp;query=%ED%98%84%EC%9E%AC%EC%83%81%EC%98%81%EC%98%81%ED%99%94" nocr="1" target="_blank"><span class="fender-ui_baf50b9a fender-ui_2900d65e fender-ui_86fe49f0 fds-thumb-small" style="--fds-comp-image-size-width:24px"><img alt="" class="fender-ui_2900d65e" height="24" src="..." width="24"/></span></a><div class="sds-comps-base-layout sds-comps-inline-layout fds-inner-box fender-ui_fde4d857 fender-ui_7108cfb0"><div class="sds-comps-base-layout sds-comps-inline-layout fds-info-text-group fender-ui_fde4d857 fender-ui_7108cfb0"><a class="fender-ui_228e3bd1 fds-info-inner-text" data-heatmap-target=".profile" href="https://in.naver.com/hyunjee1110?areacode=itb_bas%2Af_other&amp;query=%ED%98%84%EC%9E%AC%EC%83%81%EC%98%81%EC%98%81%ED%99%94" nocr="1" target="_blank"><span class="fds-comps-text fender-ui_2df0ec64">백현지</span></a></div><span class="sds-comps-base-layout sds-comps-full-layout sds-comps-divider sds-comps-divider-dot" data-sds-comp="DotDivider"></span><span class="fds-comps-text fds-info-sub-inner-text fender-ui_2df0ec64">2025.07.07.</span></div></div><div class="sds-comps-base-layout sds-comps-inline-layout fds-keep-group fender-ui_fde4d857 fender-ui_7108cfb0"><svg aria-hidden="true" class="fender-ui_08aaffd5 _keep_trigger fds-btn-keep fender-ui_5f27aa2a" data-cr-off="a=ugB_b1R*f.kep" data-cr-on="a=ugB_b1R*f.kep" data-url="https://in.naver.com/hyunjee1110/contents/internal/841834351350880" fill="none" height="13" viewbox="0.5 0.5 3 13" width="3" xmlns="http://www.w3.org/2000/svg"><path class="fender-ui_037b69cd" clip-rule="evenodd" d="M3.5 2C3.5 2.82843 2.82843 3.5 2 3.5C1.17157 3.5 0.5 2.82843 0.5 2C0.5 1.17157 1.17157 0.5 2 0.5C2.82843 0.5 3.5 1.17157 3.5 2ZM3.5 7C3.5 7.82843 2.82843 8.5 2 8.5C1.17157 8.5 0.5 7.82843 0.5 7C0.5 6.17157 1.17157 5.5 2 5.5C2.82843 5.5 3.5 6.17157 3.5 7ZM2 13.5C2.82843 13.5 3.5 12.8284 3.5 12C3.5 11.1716 2.82843 10.5 2 10.5C1.17157 10.5 0.5 11.1716 0.5 12C0.5 12.8284 1.17157 13.5 2 13.5Z" fill-rule="evenodd"></path></svg><div class="fds-keep-layer api_ly_save _keep_save_layer"><a class="spnew_af item item_save _keep_save" data-cr-off="a=ugB_b1R*f.kepoff&amp;r=1&amp;i=SYS-0000000069062660.a0209rl4_nblog_post_223924279025&amp;g=%7B%22bid%22%3A%22SYS-0000000069062660%22%2C%22docRank%22%3A1%7D" data-cr-on="a=ugB_b1R*f.kepon&amp;r=1&amp;i=SYS-0000000069062660.a0209rl4_nblog_post_223924279025&amp;g=%7B%22bid%22%3A%22SYS-0000000069062660%22%2C%22docRank%22%3A1%7D" href="#" role="button">Keep에 저장</a><a class="fender-ui_228e3bd1 spnew_af item item ...
# (function () {
#
#   var startApplication = function () {
#     var require = window.require.config({
#       "context": "fender_renderer_37298e166784b85d48f0"
#     });
#     require(["https://ssl.pstatic.net/sstatic/fe/fender/client/37298e166784b85d48f0/index.js"], function (entry) {
#       entry.bootstrap(document.getElementById("fdr-a1ccf33168974c15a54cc54369be8b52"), {"appElementAttrs":{"data-slog-container":"ugB_b1R","class":"sc_new _slog_visible"},"rootElementAttrs":{"className":"api_subject_bx"},"meta":{"area":"ugB_b1R","query":"현재상영영화","ssc":"tab.nx.all","ssuid":"intentblock","ssuidExtra":"fender_renderer-intentblock","token":"basic"},"refs":{"blockId":""},"data":{"component":"BaseLayout","props":{"className":"fds-collection-root","children":[{"component":"Header","props":{"children":[{"component":"Text","props":{"className":"fds-comps-header-headline","content":"현재상영영화 어린이"}}]}},{"component":"BaseLayout","props":{"className":"fds-ugc-block-mod-list","children":[{"component":"BaseLayout","props":{"className":"fds-ugc-block-mod","children":[{"component":"BaseLayout","props":{"className":"_keep_wrap fds-article-simple-box fds-article-box-mobilefalse","children":[{"component":"BaseLayout","props":{"className":"fds-thumb-simple-group","children":[{"component":"Anchor","props":{"cr":{"source":"*f","element":".profile","r":1,"i":"SYS-0000000069062660.a0209rl4_nblog_post_223924279025","g":"%7B%22bid%22%3A%22SYS-0000000069062660%22%2C%22docRank%22%3A1%7D"},"className":"fds-thumb-anchor","children":[{"component":"CircleImage","props":{"src":"https://search.pstatic.net/common/?src=https%3A%2F%2Fhomebuilder-phinf.pstatic.net%2F%2FMjAyMTExMTFfMTEz%2FMDAxNjM2NjM4NDgwNDI5.G-3gfnzszWes0woMnq4fmZpCLjOhskLBqtKzLBN4wn0g.6CRzDG9ZLrc0bl44EvP5NjP5acWBJJE-fjLwVYWkry4g.JPEG%2F1636638480395_GL_15_%25EC%259D%25B4%25EC%2598%2588%25EC%2597%25B4_21-11-11_25308.jpg&type=f48_48","wrapperProps":{"className":"fds-thumb-small"},"type":"24"}}],"href":"https://in.naver.com/hyunjee1110?areacode=itb_bas%2Af_other&query=%ED%98%84%EC%9E%AC%EC%83%81%EC%98%81%EC%98%81%ED%99%94"}},{"component":"BaseLayout","props":{"className":"fds-inner-box","children":[{"component":"BaseLayout","props":{"className":"fds-info-text-group","children":[{"component":"Anchor","props":{"cr":{"source":"*f","element":".profile","r":1,"i":"SYS-0000000069062660.a0209rl4_nblog_post_223924279025","g":"%7B%22bid%22%3A%22SYS-0000000069062660%22%2C%22docRank%22%3A1%7D"},"className":"fds-info-inner-text","children":[{"component":"Text","props":{"content":"백현지"}}],"href":"https://in.naver.com/hyunjee1110?areacode=itb_bas%2Af_other&query=%ED%98%84%EC%9E%AC%EC%83%81%EC%98%81%EC%98%81%ED%99%94"}}]}},{"component":"DividerLine","props":{"type":"dot.3"}},{"component":"Text","props":{"className":"fds-info-sub-inner-text","content":"2025.07.07."}}]}}]}},{"component":"BaseLayout","props":{"className":"fds-keep-group","children":[{"component":"MoreIcon","props":{"className":"_keep_trigger fds-btn-keep","data-url":"https://in.naver.com/hyunjee1110/contents/internal/841834351350880","data-cr-on":"a=ugB_b1R*f.kep","data-cr-off":"a=ugB_b1R*f.kep"}},{"component":"KeepLayer","props":{"keepOnClickLog":"a=ugB_b1R*f.kepon&r=1&i=SYS-0000000069062660.a0209rl4_nblog_post_223924279025&g=%7B%22bid%22%3A%22SYS-0000000069062660%22%2C%22docRank%22%3A1%7D","keepOffClickLog":"a=ugB_b1R*f.kepoff&r=1&i=SYS-0000000069062660.a0209rl4_nblog_post_223924279025&g=%7B%22bid%22%3A%22SYS-0000000069062660%22%2C%22docRank%22%3A1%7D","keepURL":"https://keep.naver.com/","keepLinkClickLog":{"source":"*f","element":".kephome","r":1,"i":"SYS-0000000069062660.a0209rl4_nblog_post_223924279025","g":"%7B%22bid%22%3A%22SYS-0000000069062660%22%2C%22docRank%22%3A1%7D"},"use":["keep","mykeep"]}}]}}]}},{"component":"BaseLayout","props":{"className":"fds-comps-right-image-desktop fds-ugc-body fds-comps-right-image-type-image-multi","children":[{"component":"BaseLayout","props":{"className":"fds-comps-right-image-content-container","children":[{"component":"BaseLayout","props":{"className":"fds-comps-right-image-text-container","children":[{"component":"Anchor","props":{"cr":{"source":"*f","element":".imgtitlelink","r":1,"i":"SYS-0000000069062660.a0209rl4_nblog_post_223924279025","g":"%7B%22bid%22%3A%22SYS-0000000069062660%22%2C%2 ...
#
#       }});
#     });
#   };
#
#   if (window.naver && window.naver.common && typeof window.naver.common.load_js === "function") {
#     var isDomLoading = document.readyState === "loading";
#
#     naver.common.load_js(null, startApplication, isDomLoading, 150, !isDomLoading);
#   } else {
#     setTimeout(startApplication, 150);
#   }
# })();
# </script><div class="_scrollLog" data-slog-id="ugB_b1R*f" style="visibility:hidden;height:0px;margin:0 28px"></div><div class="sc_new _slog_visible" data-block-id="web/prs_template_v2_web_basic_desk.ts" data-collection="fender_renderer" data-fender-root="true" data-meta-area="web_gen" data-meta-nscs="" data-meta-ssc="tab.nx.all" data-meta-ssuid="web" data-meta-ssuid-extra="fender_renderer-web" data-slog-container="web_gen" id="fdr-7ee4297e7faf4d939330f2c816f36ce0"><div class="NqPS577TQ7LukclHQ0FW ER5okOrgCu7G24OMsJlI desktop_mode api_subject_bx fds-root-overflow-reset"><div class="sds-comps-vertical-layout sds-comps-full-layout fds-web-root" data-template-id="layout" data-template-type="vertical"><div class="sds-comps-vertical-layout sds-comps-full-layout fds-web-list-root fds-web-list-vert-padding" data-template-id="layout" data-template-type="vertical"><div class="sds-comps-vertical-layout sds-comps-full-layout fds-web-doc-root orARx3WFGKviTwgctaP1 fds-web-normal-doc-root"><div class="sds-comps-vertical-layout sds-comps-full-layout wXXw82nfmk8rvsZ3EBn4"><div class="sds-comps-horizontal-layout sds-comps-full-layout hYXqrRZJp0NF02AvSxXb"><a class="fender-ui_228e3bd1 xymEGBxOM8YkkdoJIlrj" data-heatmap-target=".link" href="https://cinema.goheung.go.kr/?pid=32" nocr="1" target="_blank"><div class="sds-comps-horizontal-layout sds-comps-full-layout sds-comps-profile type-web size-lg title-color-g10" data-sds-comp="Profile"><div class="sds-comps-horizontal-layout sds-comps-inline-layout sds-comps-profile-source"><div class="sds-comps-horizontal-layout sds-comps-inline-layout sds-comps-profile-source-thumb"><div class="sds-comps-horizontal-layout sds-comps-inline-layout sds-comps-profile-thumbnail type-web size-lg" data-sds-comp="ProfileThumbnail"><div class="sds-comps-base-layout sds-comps-inline-layout sds-comps-image sds-comps-image-circle fit-cover is-failed" data-dimmed="none" data-sds-comp="RectangleImage" style="width:16px;height:16px;aspect-ratio:1/1"><img height="16" loading="lazy" style="display:none" width="16"/><svg aria-hidden="true" aria-label="WebBadge" class="sds-comps-svg sds-rego-web-badge sds-comps-image-fallback sds-comps-profile-thumbnail-web-badge" data-sds-comp="WebBadge" fill="none" height="16" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg"><g clip-path="url(#clip0_18669_8038)"><path d="M7.5 15.9492C5.86119 15.6268 4.48747 13.7419 3.8623 11.1494H7.5V15.9492Z"></path><path d="M12.1377 11.1494C11.5125 13.7419 10.1388 15.6268 8.5 15.9492V11.1494H12.1377Z"></path><path d="M2.73535 11.1494C2.98481 12.2836 3.36594 13.319 3.85938 14.1962C4.06171 14.5559 4.29114 14.8992 4.54395 15.2167C2.80116 14.3806 1.4087 12.9317 0.644531 11.1494H2.73535Z"></path><path d="M15.3555 11.1494C14.5912 12.932 13.1982 14.3807 11.4551 15.2167C11.708 14.899 11.9382 14.5561 12.1406 14.1962C12.6341 13.319 13.0152 12.2836 13.2646 11.1494H15.3555Z"></path><path d="M2.53906 5.95013C2.44842 6.61182 2.40039 7.29837 2.40039 7.99994C2.40039 8.70151 2.44842 9.38805 2.53906 10.0497H0.266602C0.0936272 9.39542 0 8.70863 0 7.99994C1.07376e-06 7.29124 0.0936243 6.60446 0.266602 5.95013H2.53906Z"></path><path d="M7.5 10.0497H3.64941C3.55215 9.39552 3.5 8.70851 3.5 7.99994C3.5 7.29136 3.55215 6.60435 3.64941 5.95013H7.5V10.0497Z"></path><path d="M12.3506 5.95013C12.4479 6.60435 12.5 7.29136 12.5 7.99994C12.5 8.70851 12.4479 9.39552 12.3506 10.0497H8.5V5.95013H12.3506Z"></path><path d="M15.7334 5.95013C15.9064 6.60446 16 7.29124 16 7.99994C16 8.70863 15.9064 9.39542 15.7334 10.0497H13.4609C13.5516 9.38805 13.5996 8.70151 13.5996 7.99994C13.5996 7.29837 13.5516 6.61182 13.4609 5.95013H15.7334Z"></path><path d="M4.54492 0.782165C4.29178 1.10004 4.06194 1.44355 3.85938 1.80365C3.36594 2.68087 2.98481 3.71624 2.73535 4.85052H0.644531C1.40887 3.06775 2.80159 1.61819 4.54492 0.782165Z"></path><path d="M7.5 4.85052H3.8623C4.48749 2.25791 5.86111 0.371944 7.5 0.0497428V4.85052Z"></path><path d="M8.5 0.0497428C10.1389 0.371944 11.5125 2.25791 12.13 ...
# (function () {
#
#   var startApplication = function () {
#     var require = window.require.config({
#       "context": "fender_renderer_37298e166784b85d48f0"
#     });
#     require(["https://ssl.pstatic.net/sstatic/fe/fender/client/37298e166784b85d48f0/index.js"], function (entry) {
#       entry.bootstrap(document.getElementById("fdr-7ee4297e7faf4d939330f2c816f36ce0"), {"appElementAttrs":{"className":"sc_new _slog_visible","data-collection":"fender_renderer","data-slog-container":"web_gen"},"meta":{"area":"web_gen","nscs":"","query":"현재상영영화","ssc":"tab.nx.all","ssuid":"web","ssuidExtra":"fender_renderer-web","token":"basic","xQuerySource":""},"refs":{"blockId":"web/prs_template_v2_web_basic_desk.ts"},"rootElementAttrs":{"className":"api_subject_bx fds-root-overflow-reset"},"body":{"props":{"children":[{"props":{"children":[{"props":{"aggregation":{},"bodyText":"(자막)나우 유 씨 미 3 11.12 ; (더빙/자막)위키드:포 굿 11.19 ; (자막)프레데터:죽음의 땅 11.05","bodyVariants":"3line","card":{},"clickLog":{"title":{"element":".link","g":"","i":"a00000fa_584f8c924b122a8d8be3a7d8^a","r":-1,"source":"*w"}},"deviceType":"desk","href":"https://cinema.goheung.go.kr/?pid=32","images":[{"clickLog":{"image":{"element":".simg","g":"","i":"a00000fa_584f8c924b122a8d8be3a7d8^a","source":"*w"}},"imageHref":"https://cinema.goheung.go.kr/?pid=32","imageSrc":"https://search.pstatic.net/sunny?src=https%3A%2F%2Fcinema.goheung.go.kr%2F__files%2F2025%2F10%2F3731235589_6f84851e.jpg&type=fff208_208_ar","type":"image"}],"keyValue":{},"list":{},"notice":{},"paragraph":{},"profile":{"badge":"","clickLog":{"profile":{"element":".link","g":"","i":"a00000fa_584f8c924b122a8d8be3a7d8^a","r":-1,"source":"*w"}},"favicon":"","href":"https://cinema.goheung.go.kr/?pid=32","keep":{"clickLog":{"keepLink":{"element":".kephome","g":"","i":"a00000fa_584f8c924b122a8d8be3a7d8^a","r":-1,"source":""}},"keepOffClickLog":"a=web_gen*w.kepoff","keepOnClickLog":"a=web_gen*w.keepon","keepTriggerOffClickLog":"","keepTriggerOnClickLog":"a=web_gen*w.kep","keepTriggerUrl":"https://cinema.goheung.go.kr/?pid=32","keepURL":"https://keep.naver.com/","type":"basic","use":["keep","mykeep"],"version":"2"},"subTexts":[{"text":"cinema.goheung.go.kr"}],"title":"고흥 작은영화관"},"review":{},"rootClassName":"fds-web-normal-doc-root","table":{},"title":"<mark>현재상영</mark>작 - 고흥군청","titleVariant":"1line","topstorys":{},"type":"basic"},"templateId":"webItem"},{"props":{"aggregation":{"contents":[{"bodyText":"13시 &lt;엘리지의 <mark>영화</mark>&gt; <mark>상영</mark> 후 윤재호 감독 &amp; 최지선 음악평론가 대담 3) 복원의 재구성: 이창동 전작 4K 리마스터링 포럼 일시: 7월 23일(토) 13시~15시 장소: 시네마테크KOFA 1관 모두 발언: 이창동 감독 모더레이터: 김홍준 원장 패널: 박홍열 촬영감독, 조해원 한국영상자료원 영상복원팀장, 신정민 영상복원 전문가 4) 실시간 온라인 교육 - 극장전: <mark>영화</mark>관에 관한...","clickLog":{"image":{"element":".img","g":"","i":"a00000fa_d5c724bf533b93597564986b^l","source":"*w"},"title":{"element":".link","g":"","i":"a00000fa_d5c724bf533b93597564986b","source":"*w"}},"href":"https://www.koreafilm.or.kr/cinematheque/programs/PI_01409","imageHref":"https://www.koreafilm.or.kr/cinematheque/programs/PI_01409","imageSrc":"https://search.pstatic.net/sunny?src=https%3A%2F%2Fwww.koreafilm.or.kr%2Fupload%2FprogramManage%2Fb1c8c77c-0fe6-40f5-bf02-7e0fe8dbb4d3.png&type=fff174_174","title":"시네마테크KOFA 발굴, 복원 그리고 재창조 &lt; 지난 프로그램 &lt; 프로그램 &lt; 시네마테크KOFA"}],"more":{"clickLog":{"more":{"element":".sramore","g":"","i":"a00000fa_dcddda7d5f1db9caebb89bc6^fax","source":"*w"}},"href":"?query=%ED%98%84%EC%9E%AC%EC%83%81%EC%98%81%EC%98%81%ED%99%94+site%3Awww.koreafilm.or.kr&qvt=0&where=web","text":"관련문서 더보기"}},"bodyText":"특별<mark>상영</mark> · 키즈 시네마: 파도가 끝나는 곳, 고양이의 모험이 시작된다 · 2025.11.26.수 · 플로우 총 1 편","bodyVariants":"3line","card":{},"clickLog":{"title":{"element":".link","g":"","i":"a00000fa_dcddda7d5f1db9caebb89bc6^fa","r":-1,"source":"*w"}},"deviceType":"desk","href":"https://www.koreafilm.or.kr/cinematheque/screenings","keyValue":{},"list":{},"notice":{},"paragraph":{},"profile":{"badge":"","clickLog":{"profile":{"element":".link","g":"","i":"a00000fa_dcddda7d5f1db9caebb89bc6^fa","r":-1,"source":"*w"}},"favicon":"https://search.pstatic.net/sunny?src=https%3A%2F%2Fwww.koreafilm.or.kr%2Fstatic%2Fpc%2Fimages%2Flogo%2Ffavicon.ico&type=f30_30_png_expire24","href":"https://www.koreafilm.or.kr/cinematheque/screenings","keep":{"clickLog":{"keepLink" ...
#
#       }});
#     });
#   };
#
#   if (window.naver && window.naver.common && typeof window.naver.common.load_js === "function") {
#     var isDomLoading = document.readyState === "loading";
#
#     naver.common.load_js(null, startApplication, isDomLoading, 150, !isDomLoading);
#   } else {
#     setTimeout(startApplication, 150);
#   }
# })();
# </script><div class="_scrollLog" data-slog-id="web_gen*w" style="visibility:hidden;height:0px;margin:0 28px"></div><div class="sc_new _slog_visible" data-block-id="" data-fender-root="true" data-meta-area="ugB_ctR" data-meta-nscs="" data-meta-ssc="tab.nx.all" data-meta-ssuid="intentblock" data-meta-ssuid-extra="fender_renderer-intentblock" data-slog-container="ugB_ctR" id="fdr-006d8e90855a406098b97f71a3a9173a"><div class="NqPS577TQ7LukclHQ0FW ER5okOrgCu7G24OMsJlI desktop_mode api_subject_bx"><div class="sds-comps-base-layout sds-comps-inline-layout fds-collection-root fender-ui_fde4d857 fender-ui_7108cfb0"><div class="UbnHCsVY_gMjvY4FVn7P"><div class="qO60D9BO5ZMTFlfTA7bg"><div class="RMgFtvhfCnIk3CHLIbEO"><span class="fds-comps-text fds-comps-header-headline fender-ui_2df0ec64">현재상영영화 인기 카페글</span></div></div></div><div class="sds-comps-base-layout sds-comps-inline-layout fds-ugc-block-mod-list fender-ui_fde4d857 fender-ui_7108cfb0"><div class="sds-comps-base-layout sds-comps-inline-layout fds-ugc-block-mod fender-ui_fde4d857 fender-ui_7108cfb0"><div class="sds-comps-base-layout sds-comps-inline-layout _keep_wrap fds-article-simple-box fds-article-box-mobilefalse fender-ui_fde4d857 fender-ui_7108cfb0"><div class="sds-comps-base-layout sds-comps-inline-layout fds-thumb-simple-group fender-ui_fde4d857 fender-ui_7108cfb0"><a class="fender-ui_228e3bd1 fds-thumb-anchor" data-heatmap-target=".profile" href="https://cafe.naver.com/remonterrace?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtaW50ZW50LXZpZXc=.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6InJlbW9udGVycmFjZSIsImFydGljbGVJZCI6MzM3MDE2NDEsImlzc3VlZEF0IjoxNzYzODg5Mjc5MTk4fQ.0cSZxdZhPy5laqqXxtU6sDyvkU2C-SNjcMU0XmX6kuU" nocr="1" target="_blank"><span class="fender-ui_baf50b9a fender-ui_2900d65e fender-ui_86fe49f0 fds-thumb-small" style="--fds-comp-image-size-width:24px"><img alt="" class="fender-ui_2900d65e" height="24" src="..." width="24"/></span></a><div class="sds-comps-base-layout sds-comps-inline-layout fds-inner-box fender-ui_fde4d857 fender-ui_7108cfb0"><div class="sds-comps-base-layout sds-comps-inline-layout fds-info-text-group-type2 fender-ui_fde4d857 fender-ui_7108cfb0"><a class="fender-ui_228e3bd1 fds-info-inner-text" data-heatmap-target=".profile" href="https://cafe.naver.com/remonterrace?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtaW50ZW50LXZpZXc=.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6InJlbW9udGVycmFjZSIsImFydGljbGVJZCI6MzM3MDE2NDEsImlzc3VlZEF0IjoxNzYzODg5Mjc5MTk4fQ.0cSZxdZhPy5laqqXxtU6sDyvkU2C-SNjcMU0XmX6kuU" nocr="1" target="_blank"><span class="fds-comps-text fender-ui_2df0ec64">레몬테라스 [인테리어,리폼,DIY,요리,결혼,육아,커뮤니티]</span></a><svg aria-hidden="true" class="fender-ui_08aaffd5 fender-ui_e04ddf22" fill="none" height="15" viewbox="0 0 20 15" width="20" xmlns="http://www.w3.org/2000/svg"><path d="M10.862 14.7414C10.2997 14.9101 9.70027 14.9101 9.13796 14.7414L2.49428 12.7483C1.01384 12.3042 0 10.9415 0 9.39589V1.5C0 0.671573 0.671574 0 1.5 0H18.5C19.3284 0 20 0.671573 20 1.5V9.39589C20 10.9415 18.9862 12.3042 17.5057 12.7483L10.862 14.7414Z" fill="#03C75A"></path><path clip-rule="evenodd" d="M9.44583 10.511V3H8.18553V5.75403H7.71718V3.10849H6.48242V10.1939H7.71718V6.83895H8.18553V10.511H9.44583ZM6.10817 7.70773C5.69091 7.79953 4.99264 7.8663 4.32842 7.8663V4.8786H5.92935V3.84375H3V8.93453L3.62163 8.94287C4.33694 8.95122 5.60575 8.90115 6.20184 8.75093L6.10817 7.70773ZM17 8.63677V9.74575H10.0684V8.63677H11.5756V7.44336H12.9125V8.63677H14.1218V7.44336H15.4672V8.63677H17ZM16.3442 7.0762V5.95727H15.4501L15.663 4.6804L14.459 4.55939H16.3784V3.44711H10.6475V4.55939H12.5963L11.4563 4.63868L11.6096 5.95727H10.6729V7.0762H16.3442ZM12.7769 4.55939L12.8613 5.95727H14.2238L14.3336 4.55939H12.7769Z" fill="white" fill-rule="evenodd"></path></svg></div><span class="sds-comps-base-layout sds-comps-full-layout sds-comps-divider sds-comps-divider-dot" data-sds-comp="DotDivider"></span><span class="fds-comps-tex ...
# (function () {
#
#   var startApplication = function () {
#     var require = window.require.config({
#       "context": "fender_renderer_37298e166784b85d48f0"
#     });
#     require(["https://ssl.pstatic.net/sstatic/fe/fender/client/37298e166784b85d48f0/index.js"], function (entry) {
#       entry.bootstrap(document.getElementById("fdr-006d8e90855a406098b97f71a3a9173a"), {"appElementAttrs":{"data-slog-container":"ugB_ctR","class":"sc_new _slog_visible"},"rootElementAttrs":{"className":"api_subject_bx"},"meta":{"area":"ugB_ctR","query":"현재상영영화","ssc":"tab.nx.all","ssuid":"intentblock","ssuidExtra":"fender_renderer-intentblock","token":"basic"},"refs":{"blockId":""},"data":{"component":"BaseLayout","props":{"className":"fds-collection-root","children":[{"component":"Header","props":{"children":[{"component":"Text","props":{"className":"fds-comps-header-headline","content":"현재상영영화 인기 카페글"}}]}},{"component":"BaseLayout","props":{"className":"fds-ugc-block-mod-list","children":[{"component":"BaseLayout","props":{"className":"fds-ugc-block-mod","children":[{"component":"BaseLayout","props":{"className":"_keep_wrap fds-article-simple-box fds-article-box-mobilefalse","children":[{"component":"BaseLayout","props":{"className":"fds-thumb-simple-group","children":[{"component":"Anchor","props":{"cr":{"source":"*c","element":".profile","r":1,"i":"SYS-0000000040650033.90000004_009D231802023F0900000000","g":"%7B%22bid%22%3A%22SYS-0000000040650033%22%2C%22docRank%22%3A1%7D"},"className":"fds-thumb-anchor","children":[{"component":"CircleImage","props":{"src":"https://search.pstatic.net/common/?src=http%3A%2F%2Fcafefiles.naver.net%2FMjAxNzAxMDFfOTQg%2FMDAxNDgzMjM4Nzc3NjY5.Q_CQjDV5E5xTs7PR5ZKvkgD76GkXiWmdfmB836ZQQvsg.0znV_Tkbno3J4brcnU--zljVvJLPxEwgv39EcgVsNAgg.PNG.pinkterrace%2FexternalFile.png&type=f48_48","wrapperProps":{"className":"fds-thumb-small"},"type":"24"}}],"href":"https://cafe.naver.com/remonterrace?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtaW50ZW50LXZpZXc=.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6InJlbW9udGVycmFjZSIsImFydGljbGVJZCI6MzM3MDE2NDEsImlzc3VlZEF0IjoxNzYzODg5Mjc5MTk4fQ.0cSZxdZhPy5laqqXxtU6sDyvkU2C-SNjcMU0XmX6kuU"}},{"component":"BaseLayout","props":{"className":"fds-inner-box","children":[{"component":"BaseLayout","props":{"className":"fds-info-text-group-type2","children":[{"component":"Anchor","props":{"cr":{"source":"*c","element":".profile","r":1,"i":"SYS-0000000040650033.90000004_009D231802023F0900000000","g":"%7B%22bid%22%3A%22SYS-0000000040650033%22%2C%22docRank%22%3A1%7D"},"className":"fds-info-inner-text","children":[{"component":"Text","props":{"content":"레몬테라스 [인테리어,리폼,DIY,요리,결혼,육아,커뮤니티]"}}],"href":"https://cafe.naver.com/remonterrace?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtaW50ZW50LXZpZXc=.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6InJlbW9udGVycmFjZSIsImFydGljbGVJZCI6MzM3MDE2NDEsImlzc3VlZEF0IjoxNzYzODg5Mjc5MTk4fQ.0cSZxdZhPy5laqqXxtU6sDyvkU2C-SNjcMU0XmX6kuU"}},{"component":"CafeTopImageBadge"}]}},{"component":"DividerLine","props":{"type":"dot.3"}},{"component":"Text","props":{"className":"fds-info-sub-inner-text","content":"2025.05.31."}}]}}]}},{"component":"BaseLayout","props":{"className":"fds-keep-group","children":[{"component":"MoreIcon","props":{"className":"_keep_trigger fds-btn-keep","data-url":"http://cafe.naver.com/remonterrace/33701641","data-cr-on":"a=ugB_ctR*c.kep","data-cr-off":"a=ugB_ctR*c.kep"}},{"component":"KeepLayer","props":{"keepOnClickLog":"a=ugB_ctR*c.kepon&r=1&i=SYS-0000000040650033.90000004_009D231802023F0900000000&g=%7B%22bid%22%3A%22SYS-0000000040650033%22%2C%22docRank%22%3A1%7D","keepOffClickLog":"a=ugB_ctR*c.kepoff&r=1&i=SYS-0000000040650033.90000004_009D231802023F0900000000&g=%7B%22bid%22%3A%22SYS-0000000040650033%22%2C%22docRank%22%3A1%7D","keepURL":"https://keep.naver.com/","keepLinkClickLog":{"source":"*c","element":".kephome","r":1,"i":"SYS-0000000040650033.90000004_009D231802023F0900000000","g":"%7B%22bid%22%3A%22SYS-0000000040650033%22%2C%22docRank%22%3A1%7D"},"use":["keep","mykeep"]}}]}}]}},{"component":"BaseLayout","props":{"className":"fds-comps-right-image-desktop fds-ugc-body fds-comps-right-image-type-image-basic","children":[{"component":"BaseLayout","props":{"class ...
#
#       }});
#     });
#   };
#
#   if (window.naver && window.naver.common && typeof window.naver.common.load_js === "function") {
#     var isDomLoading = document.readyState === "loading";
#
#     naver.common.load_js(null, startApplication, isDomLoading, 150, !isDomLoading);
#   } else {
#     setTimeout(startApplication, 150);
#   }
# })();
# </script><div class="_scrollLog" data-slog-id="ugB_ctR*c" style="visibility:hidden;height:0px;margin:0 28px"></div><div class="sc_new _slog_visible" data-block-id="" data-fender-root="true" data-meta-area="ugB_b2R" data-meta-nscs="" data-meta-ssc="tab.nx.all" data-meta-ssuid="intentblock" data-meta-ssuid-extra="fender_renderer-intentblock" data-slog-container="ugB_b2R" id="fdr-b6c86ab337634c30b2d09282b687082d"><div class="NqPS577TQ7LukclHQ0FW ER5okOrgCu7G24OMsJlI desktop_mode api_subject_bx"><div class="sds-comps-base-layout sds-comps-inline-layout fds-collection-root fender-ui_fde4d857 fender-ui_7108cfb0"><div class="UbnHCsVY_gMjvY4FVn7P"><div class="qO60D9BO5ZMTFlfTA7bg"><div class="RMgFtvhfCnIk3CHLIbEO"><span class="fds-comps-text fds-comps-header-headline fender-ui_2df0ec64">현재상영중인영화</span></div></div></div><div class="sds-comps-base-layout sds-comps-inline-layout fds-ugc-block-mod-list fender-ui_fde4d857 fender-ui_7108cfb0"><div class="sds-comps-base-layout sds-comps-inline-layout fds-ugc-block-mod fender-ui_fde4d857 fender-ui_7108cfb0"><div class="sds-comps-base-layout sds-comps-inline-layout _keep_wrap fds-article-simple-box fds-article-box-mobilefalse fender-ui_fde4d857 fender-ui_7108cfb0"><div class="sds-comps-base-layout sds-comps-inline-layout fds-thumb-simple-group fender-ui_fde4d857 fender-ui_7108cfb0"><a class="fender-ui_228e3bd1 fds-thumb-anchor" data-heatmap-target=".profile" href="https://in.naver.com/hyunjee1110?areacode=itb_bas%2Af_other&amp;query=%ED%98%84%EC%9E%AC%EC%83%81%EC%98%81%EC%98%81%ED%99%94" nocr="1" target="_blank"><span class="fender-ui_baf50b9a fender-ui_2900d65e fender-ui_86fe49f0 fds-thumb-small" style="--fds-comp-image-size-width:24px"><img alt="" class="fender-ui_2900d65e" height="24" src="..." width="24"/></span></a><div class="sds-comps-base-layout sds-comps-inline-layout fds-inner-box fender-ui_fde4d857 fender-ui_7108cfb0"><div class="sds-comps-base-layout sds-comps-inline-layout fds-info-text-group fender-ui_fde4d857 fender-ui_7108cfb0"><a class="fender-ui_228e3bd1 fds-info-inner-text" data-heatmap-target=".profile" href="https://in.naver.com/hyunjee1110?areacode=itb_bas%2Af_other&amp;query=%ED%98%84%EC%9E%AC%EC%83%81%EC%98%81%EC%98%81%ED%99%94" nocr="1" target="_blank"><span class="fds-comps-text fender-ui_2df0ec64">백현지</span></a></div><span class="sds-comps-base-layout sds-comps-full-layout sds-comps-divider sds-comps-divider-dot" data-sds-comp="DotDivider"></span><span class="fds-comps-text fds-info-sub-inner-text fender-ui_2df0ec64">2024.07.26.</span></div></div><div class="sds-comps-base-layout sds-comps-inline-layout fds-keep-group fender-ui_fde4d857 fender-ui_7108cfb0"><svg aria-hidden="true" class="fender-ui_08aaffd5 _keep_trigger fds-btn-keep fender-ui_5f27aa2a" data-cr-off="a=ugB_b2R*f.kep" data-cr-on="a=ugB_b2R*f.kep" data-url="https://in.naver.com/hyunjee1110/contents/internal/719680459025248" fill="none" height="13" viewbox="0.5 0.5 3 13" width="3" xmlns="http://www.w3.org/2000/svg"><path class="fender-ui_037b69cd" clip-rule="evenodd" d="M3.5 2C3.5 2.82843 2.82843 3.5 2 3.5C1.17157 3.5 0.5 2.82843 0.5 2C0.5 1.17157 1.17157 0.5 2 0.5C2.82843 0.5 3.5 1.17157 3.5 2ZM3.5 7C3.5 7.82843 2.82843 8.5 2 8.5C1.17157 8.5 0.5 7.82843 0.5 7C0.5 6.17157 1.17157 5.5 2 5.5C2.82843 5.5 3.5 6.17157 3.5 7ZM2 13.5C2.82843 13.5 3.5 12.8284 3.5 12C3.5 11.1716 2.82843 10.5 2 10.5C1.17157 10.5 0.5 11.1716 0.5 12C0.5 12.8284 1.17157 13.5 2 13.5Z" fill-rule="evenodd"></path></svg><div class="fds-keep-layer api_ly_save _keep_save_layer"><a class="spnew_af item item_save _keep_save" data-cr-off="a=ugB_b2R*f.kepoff&amp;r=1&amp;i=SYS-0000000029048545.a0209rl4_nblog_post_223526805800&amp;g=%7B%22bid%22%3A%22SYS-0000000029048545%22%2C%22docRank%22%3A1%7D" data-cr-on="a=ugB_b2R*f.kepon&amp;r=1&amp;i=SYS-0000000029048545.a0209rl4_nblog_post_223526805800&amp;g=%7B%22bid%22%3A%22SYS-0000000029048545%22%2C%22docRank%22%3A1%7D" href="#" role="button">Keep에 저장</a><a class="fender-ui_228e3bd1 spnew_af item item_q ...
# (function () {
#
#   var startApplication = function () {
#     var require = window.require.config({
#       "context": "fender_renderer_37298e166784b85d48f0"
#     });
#     require(["https://ssl.pstatic.net/sstatic/fe/fender/client/37298e166784b85d48f0/index.js"], function (entry) {
# ...
#
#       }});
#     });
#   };
#
#   if (window.naver && window.naver.common && typeof window.naver.common.load_js === "function") {
#     var isDomLoading = document.readyState === "loading";
#
#     naver.common.load_js(null, startApplication, isDomLoading, 150, !isDomLoading);
#   } else {
#     setTimeout(startApplication, 150);
#   }
# })();
# </script><div class="_scrollLog" data-slog-id="kwL_ssT" style="visibility:hidden;height:0px;margin:0 28px"></div><div class="api_sc_page_wrap"><div class="sc_page"><a aria-disabled="true" class="btn_prev" role="button"><i class="spnew api_ico_pg_arr">이전</i></a><div class="sc_page_inner"><a aria-pressed="true" class="btn" href="?nso=&amp;query=%ED%98%84%EC%9E%AC%EC%83%81%EC%98%81%EC%98%81%ED%99%94&amp;sm=tab_pge&amp;where=nexearch" onclick='goOtherCR(this,"a=pag.pag&amp;r=1&amp;i=&amp;u="+urlencode(this.href))' role="button">1</a>
# <a aria-pressed="false" class="btn" href="?nso=&amp;page=2&amp;query=%ED%98%84%EC%9E%AC%EC%83%81%EC%98%81%EC%98%81%ED%99%94&amp;sm=tab_pge&amp;start=1&amp;where=web" onclick='goOtherCR(this,"a=pag.pag&amp;r=2&amp;i=&amp;u="+urlencode(this.href))' role="button">2</a>
# <a aria-pressed="false" class="btn" href="?nso=&amp;page=3&amp;query=%ED%98%84%EC%9E%AC%EC%83%81%EC%98%81%EC%98%81%ED%99%94&amp;sm=tab_pge&amp;start=16&amp;where=web" onclick='goOtherCR(this,"a=pag.pag&amp;r=3&amp;i=&amp;u="+urlencode(this.href))' role="button">3</a>
# <a aria-pressed="false" class="btn" href="?nso=&amp;page=4&amp;query=%ED%98%84%EC%9E%AC%EC%83%81%EC%98%81%EC%98%81%ED%99%94&amp;sm=tab_pge&amp;start=31&amp;where=web" onclick='goOtherCR(this,"a=pag.pag&amp;r=4&amp;i=&amp;u="+urlencode(this.href))' role="button">4</a>
# <a aria-pressed="false" class="btn" href="?nso=&amp;page=5&amp;query=%ED%98%84%EC%9E%AC%EC%83%81%EC%98%81%EC%98%81%ED%99%94&amp;sm=tab_pge&amp;start=46&amp;where=web" onclick='goOtherCR(this,"a=pag.pag&amp;r=5&amp;i=&amp;u="+urlencode(this.href))' role="button">5</a>
# <a aria-pressed="false" class="btn" href="?nso=&amp;page=6&amp;query=%ED%98%84%EC%9E%AC%EC%83%81%EC%98%81%EC%98%81%ED%99%94&amp;sm=tab_pge&amp;start=61&amp;where=web" onclick='goOtherCR(this,"a=pag.pag&amp;r=6&amp;i=&amp;u="+urlencode(this.href))' role="button">6</a>
# <a aria-pressed="false" class="btn" href="?nso=&amp;page=7&amp;query=%ED%98%84%EC%9E%AC%EC%83%81%EC%98%81%EC%98%81%ED%99%94&amp;sm=tab_pge&amp;start=76&amp;where=web" onclick='goOtherCR(this,"a=pag.pag&amp;r=7&amp;i=&amp;u="+urlencode(this.href))' role="button">7</a>
# <a aria-pressed="false" class="btn" href="?nso=&amp;page=8&amp;query=%ED%98%84%EC%9E%AC%EC%83%81%EC%98%81%EC%98%81%ED%99%94&amp;sm=tab_pge&amp;start=91&amp;where=web" onclick='goOtherCR(this,"a=pag.pag&amp;r=8&amp;i=&amp;u="+urlencode(this.href))' role="button">8</a>
# <a aria-pressed="false" class="btn" href="?nso=&amp;page=9&amp;query=%ED%98%84%EC%9E%AC%EC%83%81%EC%98%81%EC%98%81%ED%99%94&amp;sm=tab_pge&amp;start=106&amp;where=web" onclick='goOtherCR(this,"a=pag.pag&amp;r=9&amp;i=&amp;u="+urlencode(this.href))' role="button">9</a>
# <a aria-pressed="false" class="btn" href="?nso=&amp;page=10&amp;query=%ED%98%84%EC%9E%AC%EC%83%81%EC%98%81%EC%98%81%ED%99%94&amp;sm=tab_pge&amp;start=121&amp;where=web" onclick='goOtherCR(this,"a=pag.pag&amp;r=10&amp;i=&amp;u="+urlencode(this.href))' role="button">10</a></div><a aria-disabled="false" class="btn_next" href="?nso=&amp;page=2&amp;query=%ED%98%84%EC%9E%AC%EC%83%81%EC%98%81%EC%98%81%ED%99%94&amp;sm=tab_pge&amp;start=1&amp;where=web" onclick='goOtherCR(this,"a=pag.pag&amp;r=2&amp;i=&amp;u="+urlencode(this.href))' role="button"><i class="spnew api_ico_pg_arr">다음</i></a></div></div><div class="ct_feed_wrap"></div><div class="_scrollLogEndline" style="visibility:hidden;height:0px"></div></link></link></div><div class="sub_pack" id="sub_pack"><section class="sc_new sp_related" id="nx_right_related_keywords"> <div class="api_subject_bx _related_box"> <div class="mod_title_area"> <div class="title_wrap"> <h2 class="title">연관 검색어</h2> <span class="sub"><a class="api_ad_link" href="https://help.naver.com/alias/search/word/word_1.naver" onclick="return goOtherCR(this, 'a=rsk_top.guide&amp;r=&amp;i=&amp;u='+urlencode(urlexpand(this.href)));" role="button" target="_blank"><i class="spnew api_ico_help">도움말</i></a></span> </div> <div class="title_sub"> <a class="btn_report" href="https://help.naver.com/support/alias/search/word/word_2.naver" onclick="return goOtherCR(this, 'a=rsk_top.report&amp;r=&amp;i=&amp;u='+urlencode(urlexpand(this.href)));" target="_blank"><span class="txt">신고</span></a><a class="btn_close _close" href="#" onclick="return tCR('a=rsk_top.1fold&amp;r=1&amp;i=');"><i class="spnew api_ico_close4">검색어제안 기능 닫기</i></a> </div> </div> <div class="related_srch"> <ul class="lst_related_srch _list_box"> <li class="item"> <a class="keyword" href="?ssc=tab.nx.all&amp;query=%ED%98%84%EC%9E%AC%EC%83%81%EC%98%81%EC%98%81%ED%99%94+%EC%88%9C%EC%9C%84&amp;sm=tab_she&amp;qdt=0" onclick="return goOtherCR(this, 'a=rsk_top*q.list1&amp;r=1&amp;u=' + urlencode(this.href))"> <div class="tit">현재상영영화 순위</div> </a> </li> <li class="item"> <a class="keyword" href="?ssc=tab.nx.all&amp;query=%ED%98%84%EC%9E%AC+%EC%83%81%EC%98%81+%EC%98%81%ED%99%94+%EC%88%9C%EC%9C%84+1%EC%9C%84&amp;sm=tab_she&amp;qdt=0" onclick="return goOtherCR(this, 'a=rsk_top*a.list1&amp;r=2&amp;u=' + urlencode(this.href))"> <div class="tit">현재 상영 영화 순위 1위</div> </a> </li> <li class="item"> <a class="keyword" href="?ssc=tab.nx.all&amp;query=%ED%98%84%EC%9E%AC%EC%83%81%EC%98%81%EC%98%81%ED%99%94+%EC%B6%94%EC%B2%9C&amp;sm=tab_she&amp;qdt=0" onclick="return goOtherCR(this, 'a=rsk_top*a.list1&amp;r=3&amp;u=' + urlencode(this.href))"> <div class="tit">현재상영영화 추천</div> </a> </li> <li class="item"> <a class="keyword" href="?ssc=tab.nx.all&amp;query=%ED%98%84%EC%9E%AC%EC%83%81%EC%98%81%EC%98%81%ED%99%94+%EA%B3%B5%ED%8F%AC&amp;sm=tab_she&amp;qdt=0" onclick="return goOtherCR(this, 'a=rsk_top*q.list1&amp;r=4&amp;u=' + urlencode(this.href))"> <div class="tit">현재상영영화 공포</div> </a> </li> <li class="item"> <a class="keyword" href="?ssc=tab.nx.all&amp;query=%ED%98%84%EC%9E%AC%EC%83%81%EC%98%81%EC%98%81%ED%99%94+%EC%96%B4%EB%A6%B0%EC%9D%B4&amp;sm=tab_she&amp;qdt=0" onclick="return goOtherCR(this, 'a=rsk_top*a.list1&amp;r=5&amp;u=' + urlencode(this.href))"> <div class="tit">현재상영영화 어린이</div> </a> </li> <li class="item"> <a class="keyword" href="?ssc=tab.nx.all&amp;query=10%EC%9B%94+%ED%98%84%EC%9E%AC%EC%83%81%EC%98%81+%EC%98%81%ED%99%94+%EC%88%9C%EC%9C%84&amp;sm=tab_she&amp;qdt=0" onclick="return goOtherCR(this, 'a=rsk_top*a.list1&amp;r=6&amp;u=' + urlencode(this.href))"> <div class="tit">10월 현재상영 영화 순위</div> </a> </li> <li class="item"> <a class="keyword" href="?ssc=tab.nx.all&amp;query=%ED%98%84%EC%9E%AC%EC%83%81%EC%98%81%EC%98%81%ED%99%94+%EA%B4%80%EA%B0%9D%EC%88%98+%ED%8F%89%EC%A0%90%EC%88%9C&amp;sm=tab_she&amp;qdt=0" onclick="return goOtherCR(this, 'a=rsk_top*a.list1&amp;r=7&amp;u=' + urlencode(this.href))"> <div class="tit">현재상영영화 관객수 평점순</div> </a> </li> <li class="item"> <a class=" ...
# (function () {
#
#   var startApplication = function () {
#     var require = window.require.config({
#       "context": "fender_renderer_37298e166784b85d48f0"
#     });
#     require(["https://ssl.pstatic.net/sstatic/fe/fender/client/37298e166784b85d48f0/index.js"], function (entry) {
#       entry.bootstrap(document.getElementById("fdr-4cd18f61f2cd4ccea2b0ab3c62d41503"), {"appElementAttrs":{"className":"sc_new","data-heatmap-area":"stX_cpT"},"meta":{"area":"stX_cpT","query":"현재상영영화","ssc":"tab.nx.all","ssuid":"shortents","ssuidExtra":"fender_renderer-shortents","token":"basic"},"refs":{"blockId":"shortents/prs_template_feed_search_shortents_compact_sub_desk.ts"},"rootElementAttrs":{"className":"api_subject_bx"},"body":{"props":{"children":[{"props":{"subIcon":{"props":{"clickLog":{"close":{"element":".ttclose","g":"","i":"","r":0,"source":"*b"},"open":{"element":".tooltip","g":"","i":"","r":0,"source":"*b"}},"content":"생성형AI를 통해 주제별로 인기 있는 콘텐츠를 자동 추출하여 요약된 정보를 보여줍니다. 일부 콘텐츠의 경우 주제와 일치하지 않는 정보가 노출될 수 있습니다.","full":true,"type":"basic"},"templateId":"sdsIconInformationPopover"},"titleTemplate":{"props":{"color":"violet","highlight":"영화","prefix":"함께 보는","showIcon":false,"subType":"desk","suffix":"숏텐츠","type":"shortents"},"templateId":"headerTitle"},"type":"basic"},"templateId":"sdsFeedSearchHeader"},{"props":{"category":"영화","color":"violet","contents":[{"category":"영화","clickLog":{"keyword":{"element":".kwd","g":"","i":"90000003_00000000000000342C73072D","nlog":{"airs_prid":"starfeed_naver","nlogEvt":{"airs":{"airs_session_id":"NBd4ETGWTpKbhqzq7xC6ig","bucket":"V0","click_shortcat":"영화","click_shortdoc":["90000003_00000000000000342C73072D"],"click_shortkey":["브레이브하트 줄거리와 결말"],"service_code":"SEARCH","session_id":"dzd+EQeJc4ET2AWzEy/IdQ==","session_starttime":"1763889279","template_code":"shortents_compact"}}},"r":1,"source":"*b"},"unfold":{"element":".unfold","g":"","i":"90000003_00000000000000342C73072D","nlog":{"airs_prid":"starfeed_naver","nlogEvt":{"airs":{"airs_session_id":"NBd4ETGWTpKbhqzq7xC6ig","bucket":"V0","click_shortcat":"영화","click_shortdoc":["90000003_00000000000000342C73072D"],"click_shortkey":["브레이브하트 줄거리와 결말"],"service_code":"SEARCH","session_id":"dzd+EQeJc4ET2AWzEy/IdQ==","session_starttime":"1763889279","template_code":"shortents_compact"}}},"r":1,"source":"*b"}},"data-gdid":"90000003_00000000000000342C73072D","date":"1일 전","imageSrc":"https://search.pstatic.net/common/?src=http%3A%2F%2Fblogfiles.naver.net%2FMjAyNTExMjJfMjQ2%2FMDAxNzYzNzQzNjA2NzU1.IQMmi-P5VYKQEOyUAS9LH2ucr1Jlw3XKQOiu11HBGJsg.XyJjPNZ0DLvhpyRUNcerERTeSTgRJ4dDzYC4mrQkwBUg.JPEG%2F%25EF%25BF%25BD%25EC%2581%25BA%25EF%25BF%25BD%25EC%2586%2595_%25E9%2587%2589%25EB%259A%25AE%25EC%25A0%2585%25EF%25BF%25BD%25EC%2594%25A0%25E9%2587%2589%25EB%259A%25B0%25EB%25B8%25AF%25EF%25BF%25BD%25EB%2593%2583_%25EF%25BF%25BD%25EC%25A0%2599%25E8%25B9%2582%25EF%25BF%25BD_%2528%25EF%25BF%25BD%25EB%2592%25AA%25EF%25BF%25BD%25EB%25A3%25B7_O%2529_%25E4%25BB%25A5%25EA%25BE%25A7%25EA%25B5%2585%25E7%2594%25B1%25EF%25BF%25BD_%25E5%25AF%2583%25EA%25B3%2595%25EC%25AD%259A29.jpeg&type=fc140_140_q75","isNew":false,"keyword":"브레이브하트 줄거리와 결말","keywordHref":"?mra=QkRS%5EU2JUX0NQbQ%3D%3D%5EU3hUX0NQdA%3D%3D&mra2=U0RC%5EU3hUX0NQdA%3D%3D&query=%EB%B8%8C%EB%A0%88%EC%9D%B4%EB%B8%8C%ED%95%98%ED%8A%B8+%EC%A4%84%EA%B1%B0%EB%A6%AC%EC%99%80+%EA%B2%B0%EB%A7%90&qvt=0&sm=tab_sht.best&where=nexearch&x_cue=%7B%22act%22%3A%22resrch%22%2C%22from%22%3A%22shortents%22%7D&x_shortents=%7B%22category%22%3A%22%EC%98%81%ED%99%94%22%2C%22gdid%22%3A%2290000003_00000000000000342C73072D%22%7D","title":"영화 브레이브하트 정보 (스포 O) 줄거리 결말"},{"category":"영화","clickLog":{"keyword":{"element":".kwd","g":"","i":"90000003_00000000000000342C78097D","nlog":{"airs_prid":"starfeed_naver","nlogEvt":{"airs":{"airs_session_id":"NBd4ETGWTpKbhqzq7xC6ig","bucket":"V0","click_shortcat":"영화","click_shortdoc":["90000003_00000000000000342C78097D"],"click_shortkey":["천국은 없다, 넷플릭스 TOP1 후기"],"service_code":"SEARCH","session_id":"dzd+EQeJc4ET2AWzEy/IdQ==","session_starttime":"1763889279","template_code":"shortents_compact"}}},"r":2,"source":"*b"},"unfold":{"element":".unfold","g":"","i":"90000003_00000000000000342C78097D","nlog":{"airs_prid":"starfeed_naver","nlogEvt":{"airs":{"airs_session_id":"NBd4ETGWTpKbhqzq7xC6ig","bucket" ...
#
#       }});
#     });
#   };
#
#   if (window.naver && window.naver.common && typeof window.naver.common.load_js === "function") {
#     var isDomLoading = document.readyState === "loading";
#
#     naver.common.load_js(null, startApplication, isDomLoading, 150, !isDomLoading);
#   } else {
#     setTimeout(startApplication, 150);
#   }
# })();
# </script><script>(function(){var a="https://ssl.pstatic.net/sstatic/fe/sfe/shortents/app-1.2.0.js",b=function(){var b=window.require.config({context:"shortents",paths:{shortents:a.replace(/\.js$/,"")}});define("jquery",[],function(){return jQuery}),b(["jquery","shortents"],function(e,f){var b=e('[data-fender-root][data-block-id^="shortents/prs_template_feed_search_shortents_compact"]:not(data-handled-for-log)').attr("data-handled-for-log",""),a=new Map,c={};function d(g,b){var a=g.querySelector('[data-event-area="component"]'),h=a.dataset.eventExtraCategory,d=JSON.parse(a.dataset.eventExtraKeywordList),i=JSON.parse(a.dataset.eventExtraGdidList),e={event:"shortentsCompactImpTrigger",nlogEvt:{imp_nsc:"tab.m.all",airs:{service_code:"SEARCH",session_id:"dzd\u002bEQeJc4ET2AWzEy/IdQ==",session_starttime:"1763889279",imp_shortcat:h,imp_shortkey:d,imp_shortdoc:i,template_code:"shortents_compact"}}},f;b&&(e.nlogEvt.load_type=b),f=d.join(","),c[f]||(c[f]=!0,window.ntm.push(e))}b.each(function(c,b){f.logExposure({el:b,callback:function(b){a[b.el]=b.intersect,a[b.el]&&d(b.el)}})}),b.on("fender-event",function(b){var c=b.detail.type,e=b.detail.eventName;c==="impressLog"&&e==="update_keyword"&&a[b.target]&&d(b.target,"reload")})})};naver.common.load_js(null,b)})()</script><section class="sc_new"> <div class="api_subject_bx"> <div class="api_common_banner"> <a class="spnew_bf item" href="https://mkt.naver.com/p1/atrb?channel_id=naver_pcsearchmktbanner&amp;campaign_id=2508-naverclip-002&amp;target=https%3A%2F%2Fmkt.naver.com%2Fclip-profile%3Freferer%3Dnaver_pcsearchmktbanner%26dtm_source%3Dnaver_pcsearchmktbanner%26dtm_medium%3Dmktatrb_etc%26dtm_campaign%3D2508-naverclip-002" nocr="" onclick="return goOtherCR(this, 'a=bnr.link1&amp;r=1&amp;i=&amp;u=' + urlencode(this.href));" target="_blank"> <div class="ico_area"><img alt="" class="ico" height="36" src="https://csearch-phinf.pstatic.net/20251118_15/1763444415343CHE5e_JPEG/760_31963112_marketing_banner_pc_icon_0_1763444415334.jpg" width="36"/></div> <div class="dsc_area"> <strong class="elss tit">모든 것들의 짧은 기록</strong> <p class="elss dsc">클립 프로필로 시작하세요</p> </div> </a> <a class="spnew_bf item" href="https://mkt.naver.com/p1/atrb?channel_id=naver_pcsearchmktbanner&amp;campaign_id=2510-shopping-018&amp;material=breadW&amp;target=https%3A%2F%2Fmkt.naver.com%2Fstore_discovery%3Fdtm_detail%3DbreadW%26dtm_source%3Dnaver_pcsearchmktbanner%26dtm_medium%3Dmktatrb_etc%26dtm_campaign%3D2510-shopping-018%23recomm" nocr="" onclick="return goOtherCR(this, 'a=bnr.link2&amp;r=2&amp;i=&amp;u=' + urlencode(this.href));" target="_blank"> <div class="ico_area"><img alt="" class="ico" height="36" src="https://csearch-phinf.pstatic.net/20251111_39/1762863362528LYVeE_JPEG/760_31963112_marketing_banner_pc_icon_1_1762863362520.jpg" width="36"/></div> <div class="dsc_area"> <strong class="elss tit">네이버+ 스토어를 새롭게 발견해 보세요</strong> <p class="elss dsc">내가 사랑한 스토어부터 사랑하게 될 스토어까지</p> </div> </a> <a class="spnew_bf item" href="https://mkt.naver.com/p1/atrb?channel_id=naver_pcsearchmktbanner&amp;campaign_id=2509-shopping-007&amp;target=https%3A%2F%2Fshopping.naver.com%2Fkurlynmart%2Fhome%3Fdtm_source%3Dnaver_pcsearchmktbanner%26dtm_medium%3Dmktatrb_etc%26dtm_campaign%3D2509-shopping-007" nocr="" onclick="return goOtherCR(this, 'a=bnr.link3&amp;r=3&amp;i=&amp;u=' + urlencode(this.href));" target="_blank"> <div class="ico_area"><img alt="" class="ico" height="36" src="https://csearch-phinf.pstatic.net/20250912_289/1757672730684gfUOz_JPEG/760_31963112_marketing_banner_pc_icon_2_1757672730670.jpg" width="36"/></div> <div class="dsc_area"> <strong class="elss tit">네이버에서 컬리를</strong> <p class="elss dsc">멤버십 2만원 이상 무료배송</p> </div> </a> <a class="spnew_bf item" href="https://mkt.naver.com/p1/atrb?channel_id=naver_pcsearchmktbanner&amp;campaign_id=2511-navermap-003&amp;material=1&amp;target=https%3A%2F%2Fmkt.naver.com%2F2025navermaps%2Fteaser%3Fdtm_detail%3D1%26dtm_source%3Dnaver_pcsearchmktbanner%26dtm_medium%3Dmktatrb_etc%26dtm_campai ...

# %%
# ------------------------------------------------------
# 2) 영화 정보 파싱
# ------------------------------------------------------
def parse_naver_current_movies(htmlBS):
    movies = []

    # card_item 하나가 영화 하나
    cards = htmlBS.select("div.card_item") ## 영화 자체 하나가 card_item안에 들어있음

    for card in cards: ## 영화 자체를 하나씩 가져와서 확인

        # 제목
        ## 제목이 들어있는 a태그를 찾아라
        title_tag = card.select_one("div.title.multi_line._ellipsis a") ## 여기 안에 제목 들어있음
        if not title_tag:
            continue
        title = title_tag.get_text(strip=True) ## 안에있는 텍스틑 뽑기

        # 장르
        genre = None
        overview_dl = card.select_one("dl.info_group") ## 여기 안에 개요 들어있음
        if overview_dl: ## 값이 있으면
            dd_tags = overview_dl.select("dd") # /dd 선택
            if len(dd_tags) >= 1: ## 장르랑 러닝타임이 같이 들어와서, 장르만 선택
                genre = dd_tags[0].get_text(strip=True)

        # 개봉일
        release_date = None
        info_groups = card.select("dl.info_group")
        if len(info_groups) >= 2: # 안에 개요랑 개봉일이 있음. 2번을 선택하기
            release_dl = info_groups[1]   # 2번째 dl
            dd = release_dl.select_one("dd")
            if dd:
                release_date = dd.get_text(strip=True)

        # 평점
        rating = None
        # dl.info_group.type_visible 안에서 </span> 태그안에 클래스 num안에 평점이 있음
        # -> 띄워쓰기는 하위자손 이라는 뜻 / 태그명.클래스명
        rating_tag = card.select_one("dl.info_group.type_visible span.num") 
        if rating_tag:
            try:
                ## object라서 float로 변경
                rating = float(rating_tag.get_text(strip=True))
            except:
                rating = None

        ## 값 다 추가하기
        movies.append({
            "제목": title,
            "장르(개요)": genre,
            "평점": rating,
            "개봉일": release_date,
        })
    print(movies)
    return pd.DataFrame(movies)

# %%
# ------------------------------------------------------
# 평점순으로 나열하기
# ------------------------------------------------------
df = parse_naver_current_movies(htmlBS)
display(df.sort_values('평점', ascending=False))
# Out:
# [{'제목': '위키드: 포 굿', '장르(개요)': '판타지', '평점': 7.55, '개봉일': '2025.11.19.'}, {'제목': '나우 유 씨 미 3', '장르(개요)': '범죄', '평점': 7.83, '개봉일': '2025.11.12.'}, {'제목': '극장판 체인소 맨: 레제편', '장르(개요)': '애니메이션', '평점': 9.27, '개봉일': '2025.09.24.'}, {'제목': '나혼자 프린스', '장르(개요)': '코미디', '평점': 7.53, '개봉일': '2025.11.19.'}, {'제목': '국보', '장르(개요)': '드라마', '평점': 9.1, '개봉일': '2025.11.19.'}, {'제목': '프레데터: 죽음의 땅', '장르(개요)': 'SF', '평점': 8.62, '개봉일': '2025.11.05.'}, {'제목': '퍼스트 라이드', '장르(개요)': '코미디', '평점': 7.57, '개봉일': '2025.10.29.'}, {'제목': '8번 출구', '장르(개요)': '스릴러', '평점': 8.36, '개봉일': '2025.10.22.'}]
#                제목 장르(개요)    평점          개봉일
# 2  극장판 체인소 맨: 레제편  애니메이션  9.27  2025.09.24.
# 4              국보    드라마  9.10  2025.11.19.
# 5     프레데터: 죽음의 땅     SF  8.62  2025.11.05.
# 7           8번 출구    스릴러  8.36  2025.10.22.
# 1      나우 유 씨 미 3     범죄  7.83  2025.11.12.
# 6         퍼스트 라이드    코미디  7.57  2025.10.29.
# 0        위키드: 포 굿    판타지  7.55  2025.11.19.
# 3         나혼자 프린스    코미디  7.53  2025.11.19.

# %%
# ------------------------------------------------------
# 장르별 영화 수 / 평균 평점
# ------------------------------------------------------
## 장르별 개수 확인하는 코드
# print("\n=== 장르(개요) 분포 ===")
# print(df["장르(개요)"].value_counts())

def genre_analysis(df: pd.DataFrame):
    # 장르가 비어있지 않은 것만
    valid = df[df["장르(개요)"] != ""].copy()

    # 장르별 개수와 평균 평점
    genre_group = valid.groupby("장르(개요)")["평점"].agg(["count", "mean"]).reset_index()
    genre_group = genre_group.rename(columns={
        "장르(개요)": "장르",
        "count": "영화편수",
        "mean": "평균평점"
    }).sort_values("평균평점", ascending=False)

    print("=== 장르별 영화 수 / 평균 평점 ===")
    display(genre_group)

    return genre_group


genre_stats = genre_analysis(df)
# Out:
# === 장르별 영화 수 / 평균 평점 ===
#       장르  영화편수  평균평점
# 4  애니메이션     1  9.27
# 1    드라마     1  9.10
# 0     SF     1  8.62
# 3    스릴러     1  8.36
# 2     범죄     1  7.84
# 5    코미디     2  7.55
# 6    판타지     1  7.54

# %% [markdown]
# ## 인사이트 도출
#
# 높은 평점을 받은 장르: 애니메이션·드라마
#
# - 둘 다 9점대 초반으로, 현재 상영작 중 관객 만족도가 가장 높은 장르.
#
# - 특히 애니메이션은 1편이지만, 최고 평점(9.27)을 기록 → "애니메이션에 대한 충성도가 높은걸로 보임"
#
# 코미디는 편수는 많지만 평균 평점은 상대적으로 낮음 (7.55, 2편)
#
# - 웃음 코드가 취향을 많이 타고, 작품별 완성도 차이가 있기 때문에
# 대중적으로는 무난하지만 "압도적 호평"까지는 잘 안 가는 장르.
#
# 판타지 장르도 7점대 중반으로 중간 수준
#
# - 시각적 볼거리·세계관은 강점이지만,
# 스토리 호불호 때문에 평점이 중간~중상 정도에 머무는 경향을 보임.
#
#
# ## 한계점
#
# 샘플의 한계
#
# - 대부분의 장르가 1편만 있는게 아쉬움
#
# - 장르 전체의 성향이라기보다는 현재 상영 중인 대표 작품의 평가를 그대로 반영한 수치입니다.
