# %% [markdown]
# ### [ 엑셀 읽어와서 분석하기 ]

# %%
## 모듈
import pandas as pd
import numpy as np

## 파일 경로 설정
DATA_FILE = './Data/데이터.xlsx'

## 파일 읽기
dataDF = pd.read_excel(DATA_FILE)
display(dataDF)

## 정보
dataDF.info()
# Out:
#           순번    년도                 모델명         제조사   유종   배기량 변속형식   복합연비  \
# 0        167  2019             718 박스터         포르쉐  휘발유  1988  자동7    9.4
# 1       1218  2019             718 박스터         포르쉐  휘발유  1988  자동7    9.3
# 2       2113  2020             718 박스터         포르쉐  휘발유  1988  자동7    9.4
# 3       2528  2020             718 박스터         포르쉐  휘발유  1988  자동7    9.3
# 4       3695  2021             718 박스터         포르쉐  휘발유  1988  자동7    9.3
# ...      ...   ...                 ...         ...  ...   ...  ...    ...
# 12445  12447  2024       한국상용1톤롱바디EV트럭          현대   전기     0   없음  2.795
# 12446   9089  2023  한국쓰리축1톤롱바디EV트럭(봉고)  주식회사 한국쓰리축   전기     0   없음    2.8
# 12447  12448  2024  한국쓰리축1톤롱바디EV트럭(봉고)  주식회사 한국쓰리축   전기     0   없음  2.895
# 12448   9090  2023  한국쓰리축1톤롱바디EV트럭(포터)  주식회사 한국쓰리축   전기     0   없음    2.8
# 12449  12449  2024  한국쓰리축1톤롱바디EV트럭(포터)  주식회사 한국쓰리축   전기     0   없음   2.84
#
#         등급 CO2배출량  ...  전비/연비  세금  보험료(26세 이상)  5년 배터리 교체비용  타이어 교체비용  \
# 0      4등급    179  ...    NaN NaN          NaN          NaN       NaN
# 1      5등급    186  ...    NaN NaN          NaN          NaN       NaN
# 2      4등급    179  ...    NaN NaN          NaN          NaN       NaN
# 3      5등급    186  ...    NaN NaN          NaN          NaN       NaN
# 4      5등급    186  ...    NaN NaN          NaN          NaN       NaN
# ...    ...    ...  ...    ...  ..          ...          ...       ...
# 12445  5등급      0  ...    NaN NaN          NaN          NaN       NaN
# 12446  5등급      0  ...    NaN NaN          NaN          NaN       NaN
# 12447  5등급      0  ...    NaN NaN          NaN          NaN       NaN
# 12448  5등급      0  ...    NaN NaN          NaN          NaN       NaN
# 12449  5등급      0  ...    NaN NaN          NaN          NaN       NaN
#
#        엔진오일 교체비용  브레이크오일 교체비용  보조배터리 교체비용  구동배터리 교체비용  요소수
# 0            NaN          NaN         NaN         NaN  NaN
# 1            NaN          NaN         NaN         NaN  NaN
# 2            NaN          NaN         NaN         NaN  NaN
# 3            NaN          NaN         NaN         NaN  NaN
# 4            NaN          NaN         NaN         NaN  NaN
# ...          ...          ...         ...         ...  ...
# 12445        NaN          NaN         NaN         NaN  NaN
# 12446        NaN          NaN         NaN         NaN  NaN
# 12447        NaN          NaN         NaN         NaN  NaN
# 12448        NaN          NaN         NaN         NaN  NaN
# 12449        NaN          NaN         NaN         NaN  NaN
#
# [12450 rows x 22 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12450 entries, 0 to 12449
# Data columns (total 22 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   순번           12450 non-null  object
#  1   년도           12450 non-null  object
#  2   모델명          12450 non-null  object
#  3   제조사          12450 non-null  object
#  4   유종           12450 non-null  object
#  5   배기량          12450 non-null  object
#  6   변속형식         12450 non-null  object
#  7   복합연비         12450 non-null  object
#  8   등급           12450 non-null  object
#  9   CO2배출량       12450 non-null  object
#  10  소중대/형        0 non-null      float64
#  11  평균주행거리       0 non-null      float64
#  12  전비/연비        0 non-null      float64
#  13  세금           0 non-null      float64
#  14  보험료(26세 이상)  0 non-null      float64
#  15  5년 배터리 교체비용  0 non-null      float64
#  16  타이어 교체비용     0 non-null      float64
#  17  엔진오일 교체비용    0 non-null      float64
#  18  브레이크오일 교체비용  0 non-null      float64
#  19  보조배터리 교체비용   0 non-null      float64
#  20  구동배터리 교체비용   0 non-null      float64
#  21  요소수          0 non-null      float64
# dtypes: float64(12), object(10)
# memory usage: 2.1+ MB

# %% [markdown]
# ### 공통 작업  <hr>
# 1. 평균 주행 거리
# 2. 에너지 단가
# 3. 연비 (또는 전비)
# 4. CO2 배출량
# 5. 5년 유지비

# %%
## 하이브리드 출력 = > 전기+휘발유
dataDF = dataDF[(dataDF['유종'] == '전기+휘발유') | (dataDF['등급'] == 'PHEV') | (dataDF['등급'] == 'HEV') ]
dataDF
# Out:
#           순번    년도                                모델명  제조사      유종   배기량 변속형식  \
# 391     8658  2022                A7 55 TFSI e uattro  아우디  전기+휘발유  1984  자동7
# 392     9140  2024                A7 55 TFSI e uattro  아우디  전기+휘발유  1984   자동
# 393     9141  2024                A7 55 TFSI e uattro  아우디  전기+휘발유  1984   자동
# 657     6591  2022                           BMW 320e  BMW  전기+휘발유  1998  자동8
# 658     7760  2022                           BMW 320e  BMW  전기+휘발유  1998  자동8
# ...      ...   ...                                ...  ...     ...   ...  ...
# 12231   5450  2021  페라리 SF90 Stradale Assetto Fiorano  페라리  전기+휘발유  3990  자동8
# 12232   8239  2022  페라리 SF90 Stradale Assetto Fiorano  페라리  전기+휘발유  3990  자동8
# 12233  12384  2024  페라리 SF90 Stradale Assetto Fiorano  페라리  전기+휘발유  3990   자동
# 12234  12385  2024                 페라리 SF90 XX Spider  페라리  전기+휘발유  3990   자동
# 12235  12386  2024               페라리 SF90 XX Stradale  페라리  전기+휘발유  3990   자동
#
#             복합연비    등급 CO2배출량  ...  전비/연비  세금  보험료(26세 이상)  5년 배터리 교체비용  \
# 391     3 / 11.3  PHEV   45.6  ...    NaN NaN          NaN          NaN
# 392       15.535  PHEV     45  ...    NaN NaN          NaN          NaN
# 393        15.77  PHEV     46  ...    NaN NaN          NaN          NaN
# 657     3.3 / 11  PHEV     50  ...    NaN NaN          NaN          NaN
# 658     3.3 / 11  PHEV     35  ...    NaN NaN          NaN          NaN
# ...          ...   ...    ...  ...    ...  ..          ...          ...
# 12231  2.7 / 7.4  PHEV    163  ...    NaN NaN          NaN          NaN
# 12232  2.7 / 7.4  PHEV    163  ...    NaN NaN          NaN          NaN
# 12233     11.175  PHEV    163  ...    NaN NaN          NaN          NaN
# 12234     10.415  PHEV    128  ...    NaN NaN          NaN          NaN
# 12235     10.415  PHEV    128  ...    NaN NaN          NaN          NaN
#
#        타이어 교체비용  엔진오일 교체비용  브레이크오일 교체비용  보조배터리 교체비용  구동배터리 교체비용  요소수
# 391         NaN        NaN          NaN         NaN         NaN  NaN
# 392         NaN        NaN          NaN         NaN         NaN  NaN
# 393         NaN        NaN          NaN         NaN         NaN  NaN
# 657         NaN        NaN          NaN         NaN         NaN  NaN
# 658         NaN        NaN          NaN         NaN         NaN  NaN
# ...         ...        ...          ...         ...         ...  ...
# 12231       NaN        NaN          NaN         NaN         NaN  NaN
# 12232       NaN        NaN          NaN         NaN         NaN  NaN
# 12233       NaN        NaN          NaN         NaN         NaN  NaN
# 12234       NaN        NaN          NaN         NaN         NaN  NaN
# 12235       NaN        NaN          NaN         NaN         NaN  NaN
#
# [300 rows x 22 columns]

# %%
## 필터링 ##
## 제조사 선택 추출
made_by = ['BMW', 'GM', 'MINI', '기아', '닛산', 
           '르노삼성', '르노코리아자동차(주)', '벤츠', '볼보', '아우디', 
           '테슬라코리아 유한회사', '토요타', '포드', '포르쉐', '폭스바겐', '현대', '혼다']

retDF1 = dataDF[ dataDF['제조사'].isin(made_by) ]
retDF1
# Out:
#           순번    년도                      모델명  제조사      유종   배기량 변속형식      복합연비  \
# 391     8658  2022      A7 55 TFSI e uattro  아우디  전기+휘발유  1984  자동7  3 / 11.3
# 392     9140  2024      A7 55 TFSI e uattro  아우디  전기+휘발유  1984   자동    15.535
# 393     9141  2024      A7 55 TFSI e uattro  아우디  전기+휘발유  1984   자동     15.77
# 657     6591  2022                 BMW 320e  BMW  전기+휘발유  1998  자동8  3.3 / 11
# 658     7760  2022                 BMW 320e  BMW  전기+휘발유  1998  자동8  3.3 / 11
# ...      ...   ...                      ...  ...     ...   ...  ...       ...
# 11971   8548  2022    파나메라 4 E-하이브리드 이그제큐티브  포르쉐  전기+휘발유  2894  자동8   2 / 8.3
# 12007   7225  2022        파나메라 터보 S E-하이브리드  포르쉐  전기+휘발유  3996  자동8   2 / 7.5
# 12008  12318  2024        파나메라 터보 S E-하이브리드  포르쉐  전기+휘발유  3996   자동    10.545
# 12009   7380  2022  파나메라 터보 S E-하이브리드 (5인승)  포르쉐  전기+휘발유  3996  자동8   2 / 7.5
# 12010  12319  2024  파나메라 터보 S E-하이브리드 (5인승)  포르쉐  전기+휘발유  3996   자동    10.545
#
#          등급 CO2배출량  ...  전비/연비  세금  보험료(26세 이상)  5년 배터리 교체비용  타이어 교체비용  \
# 391    PHEV   45.6  ...    NaN NaN          NaN          NaN       NaN
# 392    PHEV     45  ...    NaN NaN          NaN          NaN       NaN
# 393    PHEV     46  ...    NaN NaN          NaN          NaN       NaN
# 657    PHEV     50  ...    NaN NaN          NaN          NaN       NaN
# 658    PHEV     35  ...    NaN NaN          NaN          NaN       NaN
# ...     ...    ...  ...    ...  ..          ...          ...       ...
# 11971  PHEV     85  ...    NaN NaN          NaN          NaN       NaN
# 12007  PHEV     61  ...    NaN NaN          NaN          NaN       NaN
# 12008  PHEV     61  ...    NaN NaN          NaN          NaN       NaN
# 12009  PHEV     61  ...    NaN NaN          NaN          NaN       NaN
# 12010  PHEV     61  ...    NaN NaN          NaN          NaN       NaN
#
#        엔진오일 교체비용  브레이크오일 교체비용  보조배터리 교체비용  구동배터리 교체비용  요소수
# 391          NaN          NaN         NaN         NaN  NaN
# 392          NaN          NaN         NaN         NaN  NaN
# 393          NaN          NaN         NaN         NaN  NaN
# 657          NaN          NaN         NaN         NaN  NaN
# 658          NaN          NaN         NaN         NaN  NaN
# ...          ...          ...         ...         ...  ...
# 11971        NaN          NaN         NaN         NaN  NaN
# 12007        NaN          NaN         NaN         NaN  NaN
# 12008        NaN          NaN         NaN         NaN  NaN
# 12009        NaN          NaN         NaN         NaN  NaN
# 12010        NaN          NaN         NaN         NaN  NaN
#
# [262 rows x 22 columns]

# %%
## 결측치와 정보 확인 -> unique()
display(retDF1.isnull().count())

retDF1.info()
# Out:
# 순번             262
# 년도             262
# 모델명            262
# 제조사            262
# 유종             262
# 배기량            262
# 변속형식           262
# 복합연비           262
# 등급             262
# CO2배출량         262
# 소중대/형          262
# 평균주행거리         262
# 전비/연비          262
# 세금             262
# 보험료(26세 이상)    262
# 5년 배터리 교체비용    262
# 타이어 교체비용       262
# 엔진오일 교체비용      262
# 브레이크오일 교체비용    262
# 보조배터리 교체비용     262
# 구동배터리 교체비용     262
# 요소수            262
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# Index: 262 entries, 391 to 12010
# Data columns (total 22 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   순번           262 non-null    object
#  1   년도           262 non-null    object
#  2   모델명          262 non-null    object
#  3   제조사          262 non-null    object
#  4   유종           262 non-null    object
#  5   배기량          262 non-null    object
#  6   변속형식         262 non-null    object
#  7   복합연비         262 non-null    object
#  8   등급           262 non-null    object
#  9   CO2배출량       262 non-null    object
#  10  소중대/형        0 non-null      float64
#  11  평균주행거리       0 non-null      float64
#  12  전비/연비        0 non-null      float64
#  13  세금           0 non-null      float64
#  14  보험료(26세 이상)  0 non-null      float64
#  15  5년 배터리 교체비용  0 non-null      float64
#  16  타이어 교체비용     0 non-null      float64
#  17  엔진오일 교체비용    0 non-null      float64
#  18  브레이크오일 교체비용  0 non-null      float64
#  19  보조배터리 교체비용   0 non-null      float64
#  20  구동배터리 교체비용   0 non-null      float64
#  21  요소수          0 non-null      float64
# dtypes: float64(12), object(10)
# memory usage: 47.1+ KB

# %%
## NaN 처리
retDF1 = retDF1.fillna(0)
# Out:
# C:\Users\qjadl\AppData\Local\Temp\ipykernel_18840\2505515144.py:2: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   retDF1 = retDF1.fillna(0)

# %%
## 필요한 열 
# 년도	모델명	제조사	유종	배기량	복합연비	등급	CO2배출량	소중대/형	평균주행거리	세금	
# 보험료(26세 이상)	타이어 교체비용	엔진오일 교체비용	브레이크오일 교체비용	구동배터리 교체비용	요소수	가솔린단가(원/L)	1년 유지비(원)

# 필요없는 열 삭제
retDF1 = retDF1.drop(columns = ['순번'])
retDF1 = retDF1.drop(columns = ['전비/연비'])
retDF1 = retDF1.drop(columns = ['변속형식'])
retDF1 = retDF1.drop(columns = ['보조배터리 교체비용'])
retDF1 = retDF1.drop(columns = ['5년 배터리 교체비용'])


# 기본 세팅 및 컬럼들 초기화 (중간에 값 남아있지 않도록)
retDF1['평균주행거리'] = 15000
retDF1['세금'] = 0
retDF1['보험료(26세 이상)']   = 0
retDF1['타이어 교체비용']     = 0
retDF1['엔진오일 교체비용']   = 0
retDF1['브레이크오일 교체비용'] = 0
retDF1['구동배터리 교체비용'] = 0
retDF1['요소수'] = 0
retDF1['가솔린단가(원/L)'] = 0

# 소/중/대 구분 -> 1027 data_stadard 내용 참고
# ## 소형 : 배기량 1,600cc 미만
# ## 중형 : 배기량 1,600cc 이상 2,000cc 미만
# ## 대형 : 배기량 2,000cc 이상 
retDF1['소중대/형'] = pd.cut(retDF1['배기량'],
                            bins=[0, 1600, 2000, np.inf],
                            labels=['소형', '중형', '대형'],
                            right=False                         ## 경계값 포함하는지 마는지
)

# %%
## 해당 연도와 열에 맞는 값 대입하기

## 엔진오일 -> ## 1년에 한번 -> 8 / 10 / 12


## 휘발유 기름값
# 2019 : 1471.89원
# 2020 : 1381.57원
# 2021 : 1590.46원
# 2022 : 1812.39원
# 2023 : 1643.00원
# 2024 : 1653.23원
retDF1.loc[(retDF1['년도'] == 2019), '가솔린단가(원/L)'] = 1471.89
retDF1.loc[(retDF1['년도'] == 2020), '가솔린단가(원/L)'] = 1381.57
retDF1.loc[(retDF1['년도'] == 2021), '가솔린단가(원/L)'] = 1590.46
retDF1.loc[(retDF1['년도'] == 2022), '가솔린단가(원/L)'] = 1812.39
retDF1.loc[(retDF1['년도'] == 2023), '가솔린단가(원/L)'] = 1643.00
retDF1.loc[(retDF1['년도'] == 2024), '가솔린단가(원/L)'] = 1653.23

## 브레이크오일 -> 2년에 한번 -> 1년으로 계산하면(소/중/대) = 7 / 9 / 11
retDF1.loc[(retDF1['소중대/형']) == '소형', '브레이크오일 교체비용'] = 70000
retDF1.loc[(retDF1['소중대/형']) == '중형', '브레이크오일 교체비용'] = 90000
retDF1.loc[(retDF1['소중대/형']) == '대형', '브레이크오일 교체비용'] = 110000


### ---------------------------------
### 2019년 
### ---------------------------------
### 2019년 소형
mask = (retDF1['년도'] == 2019) & (retDF1['소중대/형'] == '소형')
retDF1.loc[mask, '보험료(26세 이상)']     = 1460000
retDF1.loc[mask, '타이어 교체비용']       = 700000
retDF1.loc[mask, '엔진오일 교체비용']     = 35000
retDF1.loc[mask, '구동배터리 교체비용']   = 2500000

### 2019년 중형
mask = (retDF1['년도'] == 2019) & (retDF1['소중대/형'] == '중형')
retDF1.loc[mask, '보험료(26세 이상)']     = 1720000
retDF1.loc[mask, '타이어 교체비용']       = 800000
retDF1.loc[mask, '엔진오일 교체비용']     = 40000
retDF1.loc[mask, '구동배터리 교체비용']   = 2800000

### 2019년 대형
mask = (retDF1['년도'] == 2019) & (retDF1['소중대/형'] == '대형')
retDF1.loc[mask, '보험료(26세 이상)']     = 2100000
retDF1.loc[mask, '타이어 교체비용']       = 900000
retDF1.loc[mask, '엔진오일 교체비용']     = 45000
retDF1.loc[mask, '구동배터리 교체비용']   = 3200000


### ---------------------------------
### 2020년
### ---------------------------------
### 2020년 소형
mask = (retDF1['년도'] == 2020) & (retDF1['소중대/형'] == '소형')
retDF1.loc[mask, '보험료(26세 이상)']     = 1420000
retDF1.loc[mask, '타이어 교체비용']       = 720000
retDF1.loc[mask, '엔진오일 교체비용']     = 36000
retDF1.loc[mask, '구동배터리 교체비용']   = 2500000

### 2020년 중형
mask = (retDF1['년도'] == 2020) & (retDF1['소중대/형'] == '중형')
retDF1.loc[mask, '보험료(26세 이상)']     = 1680000
retDF1.loc[mask, '타이어 교체비용']       = 820000
retDF1.loc[mask, '엔진오일 교체비용']     = 42000
retDF1.loc[mask, '구동배터리 교체비용']   = 2800000

### 2020년 대형
mask = (retDF1['년도'] == 2020) & (retDF1['소중대/형'] == '대형')
retDF1.loc[mask, '보험료(26세 이상)']     = 2050000
retDF1.loc[mask, '타이어 교체비용']       = 900000
retDF1.loc[mask, '엔진오일 교체비용']     = 45000
retDF1.loc[mask, '구동배터리 교체비용']   = 3200000


### ---------------------------------
### 2021년
### ---------------------------------
### 2021년 소형
mask = (retDF1['년도'] == 2021) & (retDF1['소중대/형'] == '소형')
retDF1.loc[mask, '보험료(26세 이상)']     = 1350000
retDF1.loc[mask, '타이어 교체비용']       = 740000
retDF1.loc[mask, '엔진오일 교체비용']     = 38000
retDF1.loc[mask, '구동배터리 교체비용']   = 2600000

### 2021년 중형
mask = (retDF1['년도'] == 2021) & (retDF1['소중대/형'] == '중형')
retDF1.loc[mask, '보험료(26세 이상)']     = 1600000
retDF1.loc[mask, '타이어 교체비용']       = 840000
retDF1.loc[mask, '엔진오일 교체비용']     = 43000
retDF1.loc[mask, '구동배터리 교체비용']   = 2900000

### 2021년 대형
mask = (retDF1['년도'] == 2021) & (retDF1['소중대/형'] == '대형')
retDF1.loc[mask, '보험료(26세 이상)']     = 1950000
retDF1.loc[mask, '타이어 교체비용']       = 920000
retDF1.loc[mask, '엔진오일 교체비용']     = 47000
retDF1.loc[mask, '구동배터리 교체비용']   = 3300000


### ---------------------------------
### 2022년
### ---------------------------------
### 2022년 소형
mask = (retDF1['년도'] == 2022) & (retDF1['소중대/형'] == '소형')
retDF1.loc[mask, '보험료(26세 이상)']     = 1200000
retDF1.loc[mask, '타이어 교체비용']       = 760000
retDF1.loc[mask, '엔진오일 교체비용']     = 39000
retDF1.loc[mask, '구동배터리 교체비용']   = 2600000

### 2022년 중형
mask = (retDF1['년도'] == 2022) & (retDF1['소중대/형'] == '중형')
retDF1.loc[mask, '보험료(26세 이상)']     = 1450000
retDF1.loc[mask, '타이어 교체비용']       = 860000
retDF1.loc[mask, '엔진오일 교체비용']     = 45000
retDF1.loc[mask, '구동배터리 교체비용']   = 2900000

### 2022년 대형
mask = (retDF1['년도'] == 2022) & (retDF1['소중대/형'] == '대형')
retDF1.loc[mask, '보험료(26세 이상)']     = 1850000
retDF1.loc[mask, '타이어 교체비용']       = 950000
retDF1.loc[mask, '엔진오일 교체비용']     = 48000
retDF1.loc[mask, '구동배터리 교체비용']   = 3400000


### ---------------------------------
### 2023년
### ---------------------------------
### 2023년 소형
mask = (retDF1['년도'] == 2023) & (retDF1['소중대/형'] == '소형')
retDF1.loc[mask, '보험료(26세 이상)']     = 1120000
retDF1.loc[mask, '타이어 교체비용']       = 800000
retDF1.loc[mask, '엔진오일 교체비용']     = 40000
retDF1.loc[mask, '구동배터리 교체비용']   = 2700000

### 2023년 중형
mask = (retDF1['년도'] == 2023) & (retDF1['소중대/형'] == '중형')
retDF1.loc[mask, '보험료(26세 이상)']     = 1350000
retDF1.loc[mask, '타이어 교체비용']       = 900000
retDF1.loc[mask, '엔진오일 교체비용']     = 46000
retDF1.loc[mask, '구동배터리 교체비용']   = 3000000

### 2023년 대형
mask = (retDF1['년도'] == 2023) & (retDF1['소중대/형'] == '대형')
retDF1.loc[mask, '보험료(26세 이상)']     = 1700000
retDF1.loc[mask, '타이어 교체비용']       = 980000
retDF1.loc[mask, '엔진오일 교체비용']     = 50000
retDF1.loc[mask, '구동배터리 교체비용']   = 3500000


### ---------------------------------
### 2024년
### ---------------------------------
### 2024년 소형
mask = (retDF1['년도'] == 2024) & (retDF1['소중대/형'] == '소형')
retDF1.loc[mask, '보험료(26세 이상)']     = 1050000
retDF1.loc[mask, '타이어 교체비용']       = 850000
retDF1.loc[mask, '엔진오일 교체비용']     = 42000
retDF1.loc[mask, '구동배터리 교체비용']   = 2800000

### 2024년 중형
mask = (retDF1['년도'] == 2024) & (retDF1['소중대/형'] == '중형')
retDF1.loc[mask, '보험료(26세 이상)']     = 1300000
retDF1.loc[mask, '타이어 교체비용']       = 950000
retDF1.loc[mask, '엔진오일 교체비용']     = 48000
retDF1.loc[mask, '구동배터리 교체비용']   = 3000000

### 2024년 대형
mask = (retDF1['년도'] == 2024) & (retDF1['소중대/형'] == '대형')
retDF1.loc[mask, '보험료(26세 이상)']     = 1650000
retDF1.loc[mask, '타이어 교체비용']       = 1000000
retDF1.loc[mask, '엔진오일 교체비용']     = 52000
retDF1.loc[mask, '구동배터리 교체비용']   = 3600000
# Out:
# C:\Users\qjadl\AppData\Local\Temp\ipykernel_18840\4115147860.py:13: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1471.89' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   retDF1.loc[(retDF1['년도'] == 2019), '가솔린단가(원/L)'] = 1471.89

# %%
# ## 데이터 채워서 만들었으니 진행 해야하는 과정 ##
# ## 1
# # 실제 데이터를 눈으로 확인하기.

# ## 2
# ## 정보 확인
# retDF1.info()

# ## 실제값 확인
# display(retDF1.head(3))

# ## 모든 컬럼 통계값 확인   --> 이걸로 최소값, 최댓값 등을 통해 정보 확인하기 -> 결측치 확인 & 타입 확인하고 맞게 변환하기 & 가로행이 똑같으면 중복 허용해야하는지 확인하기
# display(retDF1.describe(include='all'))

# %%
## 인덱스 0부터 재설정
dataDF = dataDF.reset_index(drop=True)
dataDF['순번'] = dataDF.index + 1
dataDF
# Out:
#       순번    년도                                모델명  제조사      유종   배기량 변속형식  \
# 0      1  2022                A7 55 TFSI e uattro  아우디  전기+휘발유  1984  자동7
# 1      2  2024                A7 55 TFSI e uattro  아우디  전기+휘발유  1984   자동
# 2      3  2024                A7 55 TFSI e uattro  아우디  전기+휘발유  1984   자동
# 3      4  2022                           BMW 320e  BMW  전기+휘발유  1998  자동8
# 4      5  2022                           BMW 320e  BMW  전기+휘발유  1998  자동8
# ..   ...   ...                                ...  ...     ...   ...  ...
# 295  296  2021  페라리 SF90 Stradale Assetto Fiorano  페라리  전기+휘발유  3990  자동8
# 296  297  2022  페라리 SF90 Stradale Assetto Fiorano  페라리  전기+휘발유  3990  자동8
# 297  298  2024  페라리 SF90 Stradale Assetto Fiorano  페라리  전기+휘발유  3990   자동
# 298  299  2024                 페라리 SF90 XX Spider  페라리  전기+휘발유  3990   자동
# 299  300  2024               페라리 SF90 XX Stradale  페라리  전기+휘발유  3990   자동
#
#           복합연비    등급 CO2배출량  ...  전비/연비  세금  보험료(26세 이상)  5년 배터리 교체비용  \
# 0     3 / 11.3  PHEV   45.6  ...    NaN NaN          NaN          NaN
# 1       15.535  PHEV     45  ...    NaN NaN          NaN          NaN
# 2        15.77  PHEV     46  ...    NaN NaN          NaN          NaN
# 3     3.3 / 11  PHEV     50  ...    NaN NaN          NaN          NaN
# 4     3.3 / 11  PHEV     35  ...    NaN NaN          NaN          NaN
# ..         ...   ...    ...  ...    ...  ..          ...          ...
# 295  2.7 / 7.4  PHEV    163  ...    NaN NaN          NaN          NaN
# 296  2.7 / 7.4  PHEV    163  ...    NaN NaN          NaN          NaN
# 297     11.175  PHEV    163  ...    NaN NaN          NaN          NaN
# 298     10.415  PHEV    128  ...    NaN NaN          NaN          NaN
# 299     10.415  PHEV    128  ...    NaN NaN          NaN          NaN
#
#      타이어 교체비용  엔진오일 교체비용  브레이크오일 교체비용  보조배터리 교체비용  구동배터리 교체비용  요소수
# 0         NaN        NaN          NaN         NaN         NaN  NaN
# 1         NaN        NaN          NaN         NaN         NaN  NaN
# 2         NaN        NaN          NaN         NaN         NaN  NaN
# 3         NaN        NaN          NaN         NaN         NaN  NaN
# 4         NaN        NaN          NaN         NaN         NaN  NaN
# ..        ...        ...          ...         ...         ...  ...
# 295       NaN        NaN          NaN         NaN         NaN  NaN
# 296       NaN        NaN          NaN         NaN         NaN  NaN
# 297       NaN        NaN          NaN         NaN         NaN  NaN
# 298       NaN        NaN          NaN         NaN         NaN  NaN
# 299       NaN        NaN          NaN         NaN         NaN  NaN
#
# [300 rows x 22 columns]

# %%
## 타입 확인하기
dataDF.info()

## 타입 변환 ##
# ## 값 한개씩 확인
# print(retDF1.배기량.unique())
# print(retDF1.CO2배출량.unique())


#### 복합연비, 구동배터리 교체비용
## 타입 변화
for i in ['배기량','CO2배출량']:
    ## 결측값 처리
    retDF1[i] = retDF1[i].fillna(0)
    ## 형 변환
    retDF1[i] = retDF1[i].astype('int64')  ## 범위가 벗어나서 큰걸로 해줘야함


# 문자열(범주형) 데이터
cat_cols = ['년도', '모델명', '제조사', '유종', '등급']
for c in cat_cols:
    retDF1[c] = retDF1[c].fillna(0)
    retDF1[c] = retDF1[c].astype('string')


# 실수형 (연비/세금/보험료 등은 소수점 존재 가능)
float_cols = [
    '세금', '보험료(26세 이상)',
    '타이어 교체비용', '엔진오일 교체비용', '브레이크오일 교체비용',
    '구동배터리 교체비용', '요소수'
]
for c in float_cols:
    retDF1[c] = retDF1[c].replace('-', np.nan)  # 혹시 '-' 같은 값이 있으면 NaN 처리
    retDF1[c] = retDF1[c].astype('float64')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 22 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   순번           300 non-null    int64
#  1   년도           300 non-null    object
#  2   모델명          300 non-null    object
#  3   제조사          300 non-null    object
#  4   유종           300 non-null    object
#  5   배기량          300 non-null    object
#  6   변속형식         300 non-null    object
#  7   복합연비         300 non-null    object
#  8   등급           300 non-null    object
#  9   CO2배출량       300 non-null    object
#  10  소중대/형        0 non-null      float64
#  11  평균주행거리       0 non-null      float64
#  12  전비/연비        0 non-null      float64
#  13  세금           0 non-null      float64
#  14  보험료(26세 이상)  0 non-null      float64
#  15  5년 배터리 교체비용  0 non-null      float64
#  16  타이어 교체비용     0 non-null      float64
#  17  엔진오일 교체비용    0 non-null      float64
#  18  브레이크오일 교체비용  0 non-null      float64
#  19  보조배터리 교체비용   0 non-null      float64
#  20  구동배터리 교체비용   0 non-null      float64
#  21  요소수          0 non-null      float64
# dtypes: float64(12), int64(1), object(9)
# memory usage: 51.7+ KB

# %%
#### 복합연비 계산 ####
# 복합 연비는 '/' 있어서 따로 계산
retSR = retDF1[retDF1['년도'].isin(['2019','2020','2021','2022'])]['복합연비']
display(retSR)

EleOil = retSR.str.split('/',expand=True)
EleOil = EleOil.astype('float')

## ex) 3.4 / 9
electric_eff = EleOil[0]   
oil_eff = EleOil[1]         
year_km = 15000     ## 평균 주행거리

# 전기랑 오일 연비 비율
elec_ratio = 0.4
oil_ratio = 0.6

# 전비 연비 주행 거리 (비율곱해서 계산)
elec_km , oil_km = year_km * elec_ratio , year_km * oil_ratio

# 전기-기름 상관관계 (1 kWh = 0.086 L)
elec_to_oil = ( elec_km / electric_eff )* 0.086               # 전기사용량 = 전기주행거리 / 전기연비
oil_L = oil_km / oil_eff                                     # 휘발유사용량 = 휘발유주행거리 / 휘발유연비

# 총 연비
total_km_per_L = year_km / (oil_L + elec_to_oil)    # 평균 거리 / (기름 주행거리 + 전기->기름 전환 주행거리)

total_km_per_L = total_km_per_L.astype('float')

retDF1['복합연비'] = total_km_per_L
# Out:
# 391      3 / 11.3
# 657      3.3 / 11
# 658      3.3 / 11
# 680      3.4/11.8
# 681      3.4/11.8
#            ...
# 11969       2/8.3
# 11970     2 / 8.3
# 11971     2 / 8.3
# 12007     2 / 7.5
# 12009     2 / 7.5
# Name: 복합연비, Length: 186, dtype: object

# %%
## 변환된 타입 확인
retDF1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 262 entries, 391 to 12010
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   년도           262 non-null    string
#  1   모델명          262 non-null    string
#  2   제조사          262 non-null    string
#  3   유종           262 non-null    string
#  4   배기량          262 non-null    int64
#  5   복합연비         186 non-null    float64
#  6   등급           262 non-null    string
#  7   CO2배출량       262 non-null    int64
#  8   소중대/형        262 non-null    category
#  9   평균주행거리       262 non-null    int64
#  10  세금           262 non-null    float64
#  11  보험료(26세 이상)  262 non-null    float64
#  12  타이어 교체비용     262 non-null    float64
#  13  엔진오일 교체비용    262 non-null    float64
#  14  브레이크오일 교체비용  262 non-null    float64
#  15  구동배터리 교체비용   262 non-null    float64
#  16  요소수          262 non-null    float64
#  17  가솔린단가(원/L)   262 non-null    float64
# dtypes: category(1), float64(9), int64(3), string(5)
# memory usage: 37.2 KB

# %%
## 오름차순으로 정렬하기
retDF1 = retDF1.sort_values(by=['소중대/형','모델명','년도'])
display(retDF1)
# Out:
#          년도                      모델명  제조사      유종   배기량       복합연비    등급  \
# 1174   2019                   BMW i8  BMW  전기+휘발유  1499  19.398334  PHEV
# 1175   2020                   BMW i8  BMW  전기+휘발유  1499  19.398334  PHEV
# 1176   2021                   BMW i8  BMW  전기+휘발유  1499  19.398334  PHEV
# 1177   2022                   BMW i8  BMW  전기+휘발유  1499  19.398334  PHEV
# 1178   2024                   BMW i8  BMW  전기+휘발유  1499        NaN  PHEV
# ...     ...                      ...  ...     ...   ...        ...   ...
# 11971  2022    파나메라 4 E-하이브리드 이그제큐티브  포르쉐  전기+휘발유  2894  11.174538  PHEV
# 12007  2022        파나메라 터보 S E-하이브리드  포르쉐  전기+휘발유  3996  10.288066  PHEV
# 12008  2024        파나메라 터보 S E-하이브리드  포르쉐  전기+휘발유  3996        NaN  PHEV
# 12009  2022  파나메라 터보 S E-하이브리드 (5인승)  포르쉐  전기+휘발유  3996  10.288066  PHEV
# 12010  2024  파나메라 터보 S E-하이브리드 (5인승)  포르쉐  전기+휘발유  3996        NaN  PHEV
#
#        CO2배출량 소중대/형  평균주행거리   세금  보험료(26세 이상)   타이어 교체비용  엔진오일 교체비용  \
# 1174       42    소형   15000  0.0    1460000.0   700000.0    35000.0
# 1175       42    소형   15000  0.0    1420000.0   720000.0    36000.0
# 1176       42    소형   15000  0.0    1350000.0   740000.0    38000.0
# 1177       42    소형   15000  0.0    1200000.0   760000.0    39000.0
# 1178       42    소형   15000  0.0    1050000.0   850000.0    42000.0
# ...       ...   ...     ...  ...          ...        ...        ...
# 11971      85    대형   15000  0.0    1850000.0   950000.0    48000.0
# 12007      61    대형   15000  0.0    1850000.0   950000.0    48000.0
# 12008      61    대형   15000  0.0    1650000.0  1000000.0    52000.0
# 12009      61    대형   15000  0.0    1850000.0   950000.0    48000.0
# 12010      61    대형   15000  0.0    1650000.0  1000000.0    52000.0
#
#        브레이크오일 교체비용  구동배터리 교체비용  요소수  가솔린단가(원/L)
# 1174       70000.0   2500000.0  0.0     1471.89
# 1175       70000.0   2500000.0  0.0     1381.57
# 1176       70000.0   2600000.0  0.0     1590.46
# 1177       70000.0   2600000.0  0.0     1812.39
# 1178       70000.0   2800000.0  0.0     1653.23
# ...            ...         ...  ...         ...
# 11971     110000.0   3400000.0  0.0     1812.39
# 12007     110000.0   3400000.0  0.0     1812.39
# 12008     110000.0   3600000.0  0.0     1653.23
# 12009     110000.0   3400000.0  0.0     1812.39
# 12010     110000.0   3600000.0  0.0     1653.23
#
# [262 rows x 18 columns]

# %%
##
retDF1['1년 유지비(원)'] = ((retDF1['평균주행거리']/retDF1['복합연비'])*retDF1['가솔린단가(원/L)'])+retDF1['세금'] + retDF1['보험료(26세 이상)']+retDF1['타이어 교체비용']+retDF1['엔진오일 교체비용']+retDF1['브레이크오일 교체비용']
retDF1['1년 유지비(원)'] = retDF1['1년 유지비(원)'].astype(int)

display(retDF1)
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In[14], line 3
#       1 ##
#       2 retDF1['1년 유지비(원)'] = ((retDF1['평균주행거리']/retDF1['복합연비'])*retDF1['가솔린단가(원/L)'])+retDF1['세금'] + retDF1['보험료(26세 이상)']+retDF1['타이어 교체비용']+retDF1['엔진오일 교체비용']+retDF1['브레이크오일 교체비용']
# ----> 3 retDF1['1년 유지비(원)'] = retDF1['1년 유지비(원)'].astype(int)
#       5 display(retDF1)
#
# File c:\Users\qjadl\anaconda3\envs\DATA_311\Lib\site-packages\pandas\core\generic.py:6665, in NDFrame.astype(self, dtype, copy, errors)
#    6659     results = [
#    6660         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6661     ]
#    6663 else:
#    6664     # else, only a single dtype is given
# -> 6665     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6666     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6667     return res.__finalize__(self, method="astype")
#
# File c:\Users\qjadl\anaconda3\envs\DATA_311\Lib\site-packages\pandas\core\internals\managers.py:449, in BaseBlockManager.astype(self, dtype, copy, errors)
#     446 elif using_copy_on_write():
#     447     copy = False
# --> 449 return self.apply(
#     450     "astype",
#     451     dtype=dtype,
#     452     copy=copy,
#     453     errors=errors,
#     454     using_cow=using_copy_on_write(),
#     455 )
#
# File c:\Users\qjadl\anaconda3\envs\DATA_311\Lib\site-packages\pandas\core\internals\managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File c:\Users\qjadl\anaconda3\envs\DATA_311\Lib\site-packages\pandas\core\internals\blocks.py:784, in Block.astype(self, dtype, copy, errors, using_cow, squeeze)
#     781         raise ValueError("Can not squeeze with more than one column.")
#     782     values = values[0, :]  # type: ignore[call-overload]
# --> 784 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     786 new_values = maybe_coerce_values(new_values)
#     788 refs = None
#
# File c:\Users\qjadl\anaconda3\envs\DATA_311\Lib\site-packages\pandas\core\dtypes\astype.py:237, in astype_array_safe(values, dtype, copy, errors)
#     234     dtype = dtype.numpy_dtype
#     236 try:
# --> 237     new_values = astype_array(values, dtype, copy=copy)
#     238 except (ValueError, TypeError):
#     239     # e.g. _astype_nansafe can fail on object-dtype of strings
#     240     #  trying to convert to float
#     241     if errors == "ignore":
#
# File c:\Users\qjadl\anaconda3\envs\DATA_311\Lib\site-packages\pandas\core\dtypes\astype.py:182, in astype_array(values, dtype, copy)
#     179     values = values.astype(dtype, copy=copy)
#     181 else:
# --> 182     values = _astype_nansafe(values, dtype, copy=copy)
#     184 # in pandas we don't store numpy str dtypes, so convert to object
#     185 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File c:\Users\qjadl\anaconda3\envs\DATA_311\Lib\site-packages\pandas\core\dtypes\astype.py:101, in _astype_nansafe(arr, dtype, copy, skipna)
#      96     return lib.ensure_string_array(
#      97         arr, skipna=skipna, convert_na_value=False
#      98     ).reshape(shape)
#     100 elif np.issubdtype(arr.dtype, np.floating) and dtype.kind in "iu":
# --> 101     return _astype_float_to_int_nansafe(arr, dtype, copy)
#     103 elif arr.dtype == object:
#     104     # if we have a datetime/timedelta array of objects
#     105     # then coerce to datetime64[ns] and use DatetimeArray.astype
#     107     if lib.is_np_dtype(dtype, "M"):
#
# File c:\Users\qjadl\anaconda3\envs\DATA_311\Lib\site-packages\pandas\core\dtypes\astype.py:145, in _astype_float_to_int_nansafe(values, dtype, copy)
#     141 """
#     142 astype with a check preventing converting NaN to an meaningless integer value.
#     143 """
#     144 if not np.isfinite(values).all():
# --> 145     raise IntCastingNaNError(
#     146         "Cannot convert non-finite values (NA or inf) to integer"
#     147     )
#     148 if dtype.kind == "u":
#     149     # GH#45151
#     150     if not (values >= 0).all():
#
# IntCastingNaNError: Cannot convert non-finite values (NA or inf) to integer

# %%
# # 데이터 저장하기
# retDF1.to_excel("./Data/전기+휘발유_정리파일.xlsx")
